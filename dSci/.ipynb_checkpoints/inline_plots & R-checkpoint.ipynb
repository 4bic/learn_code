# %%
# Display plots in cell output
# %matplotlib inline 

import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(size=100)
y = np.random.normal(size=100)
p = plt.scatter(x, y)

# %%
# Combining R and Python
# install rpy2 and R
# %load_ext rpy2.ipython

import seaborn as sns 

df = sns.load_dataset('tips')
print (df.head())

# %R -i df
# %R library(ggplot2)
# %R print(qplot(total_bill, tip, color=time, data=df) + geom_smooth(method='lm'))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-af8e20f0ccfa> in <module>()
#       1 # Combining R and Python
#       2 # install rpy2 and R
# ----> 3 get_ipython().magic('load_ext rpy2.ipython')
#       4
#       5 import seaborn as sns
#
# /Users/4bic/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /Users/4bic/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-62> in load_ext(self, module_str)
#
# /Users/4bic/anaconda/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /Users/4bic/anaconda/lib/python3.6/site-packages/IPython/core/magics/extension.py in load_ext(self, module_str)
#      35         if not module_str:
#      36             raise UsageError('Missing module name.')
# ---> 37         res = self.shell.extension_manager.load_extension(module_str)
#      38
#      39         if res == 'already loaded':
#
# /Users/4bic/anaconda/lib/python3.6/site-packages/IPython/core/extensions.py in load_extension(self, module_str)
#      81             if module_str not in sys.modules:
#      82                 with prepended_to_syspath(self.ipython_extension_dir):
# ---> 83                     __import__(module_str)
#      84             mod = sys.modules[module_str]
#      85             if self._call_load_ipython_extension(mod):
#
# /Users/4bic/anaconda/lib/python3.6/site-packages/rpy2/ipython/__init__.py in <module>()
# ----> 1 from .rmagic import load_ipython_extension
#
# /Users/4bic/anaconda/lib/python3.6/site-packages/rpy2/ipython/rmagic.py in <module>()
#      50 # numpy and rpy2 imports
#      51
# ---> 52 import rpy2.rinterface as ri
#      53 import rpy2.robjects as ro
#      54 import rpy2.robjects.packages as rpacks
#
# /Users/4bic/anaconda/lib/python3.6/site-packages/rpy2/rinterface/__init__.py in <module>()
#      79     set the R_HOME environment variable to the R home directory, or
#      80     add the directory of the R interpreter to the PATH environment variable.
# ---> 81     """)
#      82
#      83 if not os.environ.get("R_HOME"):
#
# RuntimeError: The R home directory could not be determined.
#
#     Try to install R <https://www.r-project.org/>,
#     set the R_HOME environment variable to the R home directory, or
#     add the directory of the R interpreter to the PATH environment variable.
