# %% [markdown]
# # Entity Extratction with spaCy

# %% [markdown]
# ## Overview
#
# We're going to look for all the people mentioned in a pile of documents.
#
# ### Entites
#
# "Entities" in documents are, generally, names -- names of people, places, and things such as companies. Finding out which entities are mentioned in a trove of documents can be pretty helpful, especially when you don't previously _know_ someone or some place is included the document.
#
# There are services online that do this kind of extraction, including [DocumentCloud](https://www.documentcloud.org/) ([see how here](https://www.documentcloud.org/faq#faq-analyzing-1)), [Amazon Comprehend](https://aws.amazon.com/comprehend/features/) and [Google Natural Language](https://cloud.google.com/natural-language/).
#
# ### Using spaCy
#
# We're going to do our entity extraction right here in our notebook using a pre-trained natural language model called [spaCy](https://spacy.io/). Specifically, we're using the spaCy [large English language model](https://spacy.io/models/en#en_core_web_lg) trained on the [OntoNotes dataset](https://catalog.ldc.upenn.edu/LDC2013T19) -- a trove of "telephone conversations, newswire, newsgroups, broadcast news, broadcast conversation, weblogs" that includes nearly 1.5 million English words.
#
# The spaCy project has a lot of great language features. We'll be looking at the [named entities feature](https://spacy.io/usage/linguistic-features#named-entities). Note also that there are [models for several languages](https://spacy.io/models) being developed in spaCy.
#
#
# ## The Plan
#
# - We'll download the spaCy software and the large English language model.
# - We'll also download a (smallish) pile of emails released in a court case.
# - We'll learn how to use spaCy functions to extract entities
# - We'll use the spaCy functions to scan all the pages of the emails.

# %% [markdown]
# ## Credits
#
# This notebook was written by John Keefe [Quartz](https://qz.com) at Quartz and includes document-processing code written included in [a blog post](https://qz.ai/discovering-interesting-documents-in-the-mauritius-leaks/) and a [Jupyter notebook](https://github.com/Quartz/aistudio-doc2vec-for-investigative-journalism/blob/master/Doc2vec%20for%20Investigative%20Journalism.ipynb) by Jeremy B. Merrill at Quartz, who used it to help find documents inside a document dump known as the [Mauritius Leaks](https://qz.com/1670632/how-quartz-used-ai-to-help-reporters-search-the-mauritius-leaks/).
#
# -- John Keefe, [Quartz](https://qz.com), October 2019

# %% [markdown]
# ## Setup

# %% [markdown]
# ### For those using Google Colaboratory ...
#
# Be aware that Google Colab instances are ephemeral -- they vanish *Poof* when you close them, or after a period of sitting idle (currently 90 minutes), or if you use one for more than 12 hours.
#
# If you're using Google Colaboratory, be sure to set your runtime to "GPU" which speeds up your notebook for machine learning:
#
# ![change runtime](https://qz-aistudio-public.s3.amazonaws.com/workshops/notebook_images/change_runtime_2.jpg)
# ![pick gpu](https://qz-aistudio-public.s3.amazonaws.com/workshops/notebook_images/pick_gpu_2.jpg)

# %% [markdown]
# ### Everybody do this ...

# %% [markdown]
# Everyone needs to run the next cell, which initializes the Python libraries we'll use in this notebook.

# %%
## *EVERYBODY* SHOULD RUN THIS CELL
## This can take up to 3 minutes ... but that's normal
# %cat /usr/local/cuda/version.txt

# !pip install -U spacy[cuda100] --quiet
# !python -m spacy download en_core_web_lg
# !pip install PyPDF2 --quiet

import spacy
spacy.prefer_gpu()

import en_core_web_lg
import PyPDF2
import json
from os.path import exists

# %% [markdown]
# ## The Data

# %% [markdown]
# In this tutorial, we're going to look at some emails from the office of New York City mayor Bill de Blasio that were released under the Freedom of Information Law.
#
# The emails were part of the ["Agent of the City" hubbub](https://www.ny1.com/nyc/all-boroughs/news/2018/05/24/agents-of-the-city-emails-released), in which 4,000 city emails were released. You can download the [original file here](https://a860-openrecords.nyc.gov/response/120252?token=c784372fd140497081b4bfcff9f0e3a0) -- though we'll be using a file containing just [the first 100 pages](https://qz-aistudio-public.s3.amazonaws.com/workshops/2018.05.24_BerlinRosen_Responsive_Records_100pgs.pdf) for this exercise.

# %% [markdown]
# **Mount** **Drive** to work from

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/'My Drive'/Colab_Notebooks/ml_journalists
# Out:
# /content/drive/My Drive/Colab_Notebooks/ml_journalists

# %%
# Run this cell to download the data we'll use for this exercise
# !wget -N https://qz-aistudio-public.s3.amazonaws.com/workshops/deblasio_emails_data.zip --quiet
# !unzip -q deblasio_emails_data.zip
print('Done!')
# Out:
# Done!

# %% [markdown]
# Let's look at what we have.

# %%
# %ls data/
# Out:
# 2018.05.24_BerlinRosen_Responsive_Records_100pgs.pdf  images/
# choppers/                                             not_yet_seen.png
# imagenet_class_index.json

# %% [markdown]
# ## Trying the entity extraction feature

# %%
# First we load the model into the notebook
nlp = en_core_web_lg.load()

# %%
# Now let's give it a try
doc = nlp(u"Nairobi governor, Mike Sonko got arrested in Voi by robots")

# %% [markdown]
# There's [a whole list of entities spaCy can detect](https://spacy.io/api/annotation#named-entities)!

# %%
my_story = """Nairobi Governor Mike Sonko has arrived at the Milimani Law Court ahead of his arraignment today over graft charges at City Hall.
Sonko was transferred from the EACC headquarters under tight police security and arrived at the Milimani Law Court at exactly 7.55 am.
A contingent of heavily armed security personnel has been deployed around the court with the roads leading to the area sealed off and traffic re-directed to other adjacent roads. 
"""

doc = nlp(my_story)

# %%
for entity in doc.ents:
    print(entity.text, entity.label_, spacy.explain(entity.label_))
# Out:
# Nairobi GPE Countries, cities, states
# Mike Sonko PERSON People, including fictional
# the Milimani Law Court ORG Companies, agencies, institutions, etc.
# today DATE Absolute or relative dates or periods
# City Hall FAC Buildings, airports, highways, bridges, etc.
# Sonko PERSON People, including fictional
# EACC ORG Companies, agencies, institutions, etc.
# the Milimani Law Court ORG Companies, agencies, institutions, etc.
# 7.55 am TIME Times smaller than a day

# %% [markdown]
# ## Load the emails into a "jsonl" file
#
# JSONL is a file format that stores data in a JSON file, with each record living on its own line in the file.
#
# This next block reads the PDF file and turns it into a JSONL file, which is much easier to work with.

# %%
# read the PDF file into a new file called 'nyc_docs.jsonl'
jsonl_file = "nyc_docs.jsonl"
if not exists(jsonl_file):
    pdf_file = open('data/2018.05.24_BerlinRosen_Responsive_Records_100pgs.pdf', 'rb')
    read_pdf = PyPDF2.PdfFileReader(pdf_file)
    with open(jsonl_file, 'w') as f:
        for page_num in range(read_pdf.getNumPages()):
            page = read_pdf.getPage(page_num)
            page_content = page.extractText().encode('utf-8').decode("utf-8") 
            f.write(json.dumps({"_source": {"content": page_content}, "_id": f"p{page_num+1}"}) + "\n")

# %%
# let's take a look at the first few lines of the file
# !head nyc_docs.jsonl
# Out:
# {"_source": {"content": "  THE CITY OF NEW YORK\n OFFICE OF THE MAYOR\n NEW YORK, NY 10007\n  May \n24, 2018  Dear \nRequester\n,  This letter is in\n response to \nprevious \nrequest\ns pursuant to the Freedom of Information Law \nreceived\n by this Office, seeking\n generally\n  Correspondence between \nthe Office of the Mayor and \nJonathan Rosen or \nBerlinRosen.\n  Due to the number of FOIL requests the Mayor\u00d5s Office has received for similar \ncommunications, as a courtesy the documents being disclosed to you today include materials that \nare outside the scope\n of your requests.\n !The responsive records comprise four volumes of material:\n A. Pages 3\n-729: Material previously \nwithheld in full or in part\n pursuant to the inter\n-agency \nexemption \n\u00a487(2\n)(g) within the time range. This volume also includes 73 pages of \nmateria\nl previously withheld in full pursuant to \n\u00a487(2\n)(b).\n  Range: January 1, 2014 to April 3, 2015.\n B. Pages 730\n-2844: Material previously \nproduced\n in full or in part, \nor \nwithheld\n in full. \n  Range: April 4, 2015 to Dec 31, 2016.\n C. Pages 2845\n-4016: Material responsive \nto requests not yet fulfilled, and thus not produced \npreviously.\n  Range: January 1, 2017 to Dec 31, 2017.\n D. Pages 4017\n-4247: Material sent to a large number of recipients.\n  Range:\n April 4, 2015 to Dec 31, 2016\n  Please note that some responsive material \nis redacted in part pursuant to Public Officers Law \n\u00a487(2\n)(b). \nSome \nschedules\n have been redacted pursuant to \nPublic Officers Law \u00a487(2)\n(b); t\nhese \nredactions consist of \npersonal appointments\n or \nprivate\n information\n. Please also note that some \nresponsive materia\nl has been redacted in part pursuant to \n\u00a487(2\n)(f). \n  "}, "_id": "p1"}
# {"_source": {"content": "Additionally, attached at the end of the materials provided, \nyou will find a table containing the \nidentities of those whose personal email addresses were redacted \npursuant to Public Officers \nLaw \u00a487(2)(\nb), effectively concealing the identities of the senders and/or recipients. Please note \nthat the Mayor\u00d5s Office is not aware of all identities of email recipients and senders. Those email \nsenders and recipients who could not be identified are marked as \u00d2Unk\nnown\u00d3 on the attached \ntable. \n  You may appeal the determination with regard to this production in writing within thirty days by \naddressing such an appeal to \nfoilappeal@cityhall.nyc.gov\n.   Sincerely,\n   Jimmy Pan\n Associate Counsel\n  "}, "_id": "p2"}
# {"_source": {"content": "From:Walzak, Phil\nTo:\"Jonathan@berlinrosen.com\"; \" \"dan@berlinrosen.com\"; \"emma@berlinrosen.com\";\"Rabinowitz@berlinrosen.com\"Subject:FW: Re:Hi\nDate:Tuesday, January 07, 2014 6:43:07 PM\nAnything we can do here / want to do?\n-----Original Message-----\nFrom: Henry Goldman (BLOOMBERG/ NEWSROOM:) [\nmailto:hgoldman@bloomberg.net]Sent: Tuesday, January 07, 2014 5:47 PM\nTo: Walzak, Phil\nSubject: Re:Hi\nI've got my first request: Can you help me talk to Harvey Weinstein and/or Gwyneth Paltrow about their\nsupport for UPKNYC? Thanks, H\n----- Original Message -----\nFrom: PWalzak@cityhall.nyc.gov\nTo: Henry Goldman (BLOOMBERG/ NEWSROOM:)\nAt: Jan\n  7 2014 15:55:30\n"}, "_id": "p3"}
# {"_source": {"content": "From: To: Subject: Date: Morning, Klein, Monica \u00a5\u00a5\u00a5\u00a5\u00a5\u00a5\u00a5 Emma Wolfe; jonathan@bertinrosen.com request from bdb re: Jeff Klein & UPK Monday, January 13, 2014 9:45:43 AM BdB would like to discuss article below Thx, Monica Rejecting NYC's pre-K tax proposal could lead to statewide feud over taxes DAILY NEWS-Kenneth Lovett http://www.nydailynews.com/new-york/rejecti ng-nyc-pre-k-tax -proposal-lead-tax-feud-article-1.1577330 ALBANY-The co-leader of the state Senate is hinting that dozens of requests from municipalities could be in jeopardy if the Legislature rejects Mayor de Blasia's push to raise the city income tax on the wealthy to pay for a pre-K expansion. Under what is known as a home rule process, a municipality requests permission from the state to raise certain local taxes or take other actions.Typically, lawmakers acquiesce to the locals and the requests sail through. Over the past three years, 314 home rule b\nills were passed by the Legislature and signed into law by the governor, aides to Jeffrey Klein (D-Bronx) say. \"We cannot and must not have a double standard when it comes to home rule legislation like Mayor de Blasia's universal pre-K p\nlan,\" Klein told the Daily News. \"Either we empower cities and counties to set their own destiny, or we rethink this entire process.\" Klein made his comments after Senate Republican Leader Dean Skelos said last week that de Blasia hasn't yet made a compelling case for a city income tax hike. As co-leaders of the Senate, Klein and Skelos (R-Nassau County) each have the power to block legislation from coming to the floor for a vote. The Senate passed 138 home rule messages last year alone. Rejecting de Blasia's plan -assuming as expected the City Council officially asks for it to be passed -could cause city lawmakers to retaliate by voting against other home rule actions sought by suburban and upstate communities -if they are allowed to reach the f\nloor for a vote at all, insiders say. In supporting de Blasia's plan, Klein said h\niking the city income tax on those earning at least $500,000 will ensure a future funding stream for city prekindergarten programs and \"will guarantee 50,000 4-year-olds the opportunity to enroll in this life changing program.\" Told of Klein's comments, a Skelos spokesman said only that \"we look forward to working with our partner, "}, "_id": "p6"}
# {"_source": {"content": "!\"##$%&\"'()$*($+,'-$'--.\"/0\n1--\"23&4$56\"78\"9$5,\"&:*($5'&;\"9$7(:$,'-$<\"2*=97+'=$=*(#\"9\"(=\"$-.66*9+$+,\"$274*9>-$9\"?.\"-+$#*9$7$+7@$\n,'8\")$3.+$58\"&*-$7(:$A*;/$B.*2*$,7;\"$3\"\"($=**&$+*$+,\"$':\"7/\n"}, "_id": "p7"}
# {"_source": {"content": "From: Jonathan Rosen To: Cc: Ragone. Peter; Wolfe. Emma Subject: Re: CRAIN\"S: Mayor vs. Governor Monday, January 13, 2014 9:37:24 PM Date: -will yell at Hawkins re retro pay. It's unsourced nonsense and have seen it nowhere else. Do not think it has any currency. -re pundits defining our success: will the George Arzt's a\nnd Richard Brodsky's say inane shit if we come up short-probably -but I feel like the three scenarios we laid out last night are the only way to play and see almost no circumstance where we don't achieve some level of historic expansion of prek and after school. -new rule: all clips where Richard Brodsky is t\nhe lead analysis quote should be disregarded as a matter of course. It's like stories where Hank Sheinkopf is t\nhe only quote. Sent from my iPhone On Jan 13, 2014, at 7:41 PM, \"Bill de Blasia\" wrote: Lord knows I don't pray at brodsky's alter, but I am concerned whether people will actually believe we have failed with a Year One tax increase. I personally don't believe they will if we achieve enough other elements of our agenda AND if we get the tax done by the following year. And when did the elite decide we we\nre indirectly financing retro pay with our tax increase? That's totally false. How she we dispel that rumor? Sent via BlackBerry by AT&T From: De Blasia Clips
# {"_source": {"content": "\"If Cuomo stiffs him,\" said former Assemblyman Richard Brodsky, \"I don't\nknow how he gets through year one.\"\nMr. Brodsky, a senior fellow at public-policy institute Demos, said the\nfight on taxes will define the legislative session in Albany this spring.\n\"It looks like de Blasio has the Legislature with him,\" he said. \"If that's\nthe case, there are votes in both houses to do what he wants. Is Cuomo\ngoing to declare, 'I did my best'? It's possible. But it's not likely.\"\nThe governor has wriggled out of political boxes before. Two years ago,\nhaving pledged no tax increases but facing a budget deficit, Mr. Cuomo\ndeftly passed off a $2 billion tax increase as a reduction by extending a\n\"millionaire's tax\" just before it expired while cutting middle-class tax\nrates. Last year, he and the Legislature quietly extended the surcharge\non high earners through 2017. The governor has since been vocal about\nnot revisiting income taxes, arguing that increases on the wealthy will\nsend them fleeing to low-tax states.\nTwo-front battle\nThe tax debate will play out on two fronts. City and state officials will\nstart hashing out their differences behind closed doors, with Mr. de Blasio\nlikely to deploy his new budget director, Dean Fuleihan, who for years\nwas Mr. Silver's chief policy adviser and knows Albany intimately.\nMeanwhile, Mr. de Blasio, organized labor and the Working Families Party\nwill take their tax-the-rich message to the public in districts of key state\nlawmakers to build momentum for their cause. The playbook will be\nfamiliar: rallies, door-knocking, phone-banking and possibly TV and radio\nads.The WFP recently joined with other left-leaning groups to create People\nfor New York, modeled in part on a past adversary, the Committee to\nSave New York, a former business alliance that advertised in support of\nthe governor's fiscally conservative agenda.\nAs one source who has worked on past campaigns with the Democratic-\noperative-turned-mayor put it, Mr. de Blasio \"is a big believer in the\noutside game.\"\n-- You received this message because you are subscribed to the Google\nGroups \"de Blasio Clips\" group.\nTo unsubscribe from this group and stop receiving emails from it, send\nan email to \nbdbclips+unsubscribe@googlegroups.com.For more options, visit \nhttps://groups.google.com/groups/opt_out."}, "_id": "p10"}

# %% [markdown]
# Each line in the JSON file now represents a single page in the original document. So now we'll step through each line (aka page) and grab all the entities in the text. Then we'll print out all the entities.

# %% [markdown]
# ## Finding and listing the names

# %%
with open(jsonl_file, 'r') as f:        # open the jsonl file
    for line in f:                      # loop through each line ...
        line = json.loads(line)            # read the line 
        text = line["_source"]["content"]  # grab the text of the email
        page_number = line["_id"]          # grab the page number we're on
        doc = nlp(text)                    # load the text into the nlp model
        for ent in doc.ents:               # loop through each entity in the text...
            if (ent.label_ == "PERSON"):      # if the entity is a person's name ...
                print(page_number, ent.text)  # print the page number and the name
# Out:
# p1 Jonathan Rosen
# p1 BerlinRosen
# p2 Jimmy Pan
# p3 Phil
#
# p3 Henry Goldman
# p3 mailto
# p3 Phil
#
# p3 Harvey Weinstein
# p3 Gwyneth Paltrow
# p3 Henry Goldman
# p4 Jonathan Rosen
# p4 Ragone
# p4 Peter
# p4 De Blasia's
# p4 Ross
# p4 Bill de Blasio
# p4 Peter Ragone Cc
# p4 Jonathan Rosen
# p4 Ragone
# p4 DeBlasio Clips
# p4 DeBlasio
# p4 DeBlasio
# p4 Bill De Blasia's
# p4 John Kanas
# p4 oney
# p4 Betty Liu
# p4 De Blasia
# p5 Wilbur Ross
# p5 Steve Schwarzman
# p6 Klein
# p6 Emma Wolfe
# p6 Monica
# p6 Kenneth Lovett http://www.nydailynews.com/new-york/rejecti ng-nyc
# p6 Mayor de Blasia's
# p30 Ben
# p30 DYCD
# p30 Commlmity Pruinerships
# p31 Oskar
# p32 Adams
# p32 Marti
# p32 Rosen
# p32 Jonathan Rosen
# p32 Adams
# p32 Marti
# p32 4,-(&)"(#/0)&(4/+"5
# p32 Adams
# p32 Marti
# p32 Jonathan Rosen
# p32 Adams
# p32 Marti
# p32 Phil
# p32 Wolfe
# p32 Emma
#
# p32 48"-5I
#
# p32 Norvell
# p32 Adams
# p32 Marti
# p32 Phil
# p32 Adams
# p32 Marti
# p32 Norvell
# p32 Phil
#
# p33 Adam Dickter
# p33 Bill de Blasio
# p34 Ruth J. AbramKaren R. AdlerArlene AldaAnita
# p34 Ann-Asch
# p34 Emanuel AxPeter
# p34 BergerLoren BevansMartin I. BreslerKenneth
# p34 Rachel CowanBarbara
# p34 GreenwaldJane HirschmannErica Jong
# p35 Peter A. JosephAlice Kessler-Harris
#
# p35 Sharon KleinbaumGil
# p35 LeighAlan H. LevineRabbi
# p35 B. PogrebinMichael
# p35 RatnerAnne
# p35 Felicia SolAlisa
# p35 SteinemHerbert
# p35 Burton VisotzkyPeter Weiss
# p37 Wolfe
# p37 Emma
#
# p37 Jonathan Rosen
# p37 Pedro Noguera
# p37 Jonathan Rosen
# p37 Eliza Shapiro
#
# p37 Bill de BlasioÕs
# p37 De Blasio
# p38 Pedro Noguera
# p38 De Blasio
# p38 Andrew Cuomo
# p38 de Blasio
# p38 Cuomo
# p38 De Blasio
# p38 de BlasioÕs
# p38 Nancy Wackstein
# p38 Butexpanding
# p39 Wackstein
# p39 Anthony Marx
# p39 Marx
# p39 Devon Puglia
# p41 Jonathan Rosen
# p41 Ben Furnas
# p41 Hatch
# p41 Peter
# p41 Jonathan
# p41 Jonathan Rosen
# p41 Jonathan
# p41 njoying
# p42 Jonathan Rosen
# p42 mailto
# p42 Jonathan Rosen
# p42 Jonathan Rosen
# p42 mailto
# p43 Jonathan Rosen
# p43 H*!4.1!.3G!$%-!8.1!0
# p43 Jonathan Rosen
# p43 mailto
# p44 Wolfe
# p44 Emma
# p44 Jonathan Rosen
# p44 Rebecca Katz
# p44 gmail
# p44 Message-----From
# p44 Jonathan Rosen
# p44 Rebecca Katz
# p44 Wolfe
# p44 Sirota
# p44 Pis
# p44 David Sirota
# p44 Jonathan Rosen
# p45 Wolfe
# p45 Jonathan Rosen" RE
# p45 Jonathan Rosen
# p45 Wolfe
# p45 Wolfe
# p45 Emma
# p45 Jonathan Rosen.----PhiiWalzak
# p45 Rebecca Katz
# p45 gmail
# p45 Message-----From
# p45 Jonathan Rosen
# p45 Rebecca Katz
# p45 Wolfe
# p45 Sirota
# p45 Pis
# p45 David Sirota
# p45 Jonathan Rosen
# p46 Wolfe
# p46 Emma
#
# p46 Wolfe
# p46 Jonathan Westin'
# p46 Gabriel
#
# p46 Jonathan Westin
# p46 Wolfe
# p46 Emma
#
# p47 Jon Paul
# p47 Josh Gold
# p47 Sherif Soliman
# p47 WileyJNorvell
# p47 gmaill
# p47 Peter Ragone
# p47 Dan Levitan
# p47 Mike Rabinowitz
# p68 Katz
# p68 Rebecca
# p68 Klein
# p68 Monica
#
# p68 Saul
# p68 Michael
# p68 Katz
# p68 Katz
# p68 Rebecca [mailto:RKKatz@cityhall.nyc.gov
# p68 Saul
# p68 Michael
# p69 Dan Levitan
# p69 Katz
# p69 Klein
# p69 Monica
#
# p69 Katz
# p69 Saul
# p69 Michael
# p69 Katz
# p69 Katz
# p69 Rebecca
# p69 mailto
# p69 Saul
# p69 Michael
# p69 Mama Saul
# p71 Gwendolyn
# p71 Connie Chung
# p71 Daria Siegel
#
# p71 Nicole
# p71 Ruchi
# p71 Jason Chiusano
# p71 Connie Chung
# p71 Daria Siegel
# p71 Gwendolyn
# p71 Ruchi
# p71 Connie Chung
# p71 Daria Siegel
# p71 Gwendolyn
# p71 Connie Chung
#
# p71 Ruchi
# p71 Gwendolyn
# p71 Daria Siegel
# p71 Ruchi
# p71 Nick Cotz
# p71 Jason Chiusano
# p71 Nicole
#
# p71 Ruchi
# p72 Richard
# p72 Jason Chiusano
# p72 Nicole Kolinsky
# p72 Nicholas A. CotzArtistic
# p73 Gwendolyn
# p73 Nicole Kolinsky
# p73 Deborah Morris
# p73 Daria Siegel
# p73 Gwendolyn
# p73 Connie Chung'
# p73 Nicole Kolinsky
# p73 Deborah
# MorrisSubject
# p73 Pigeoning
# p73 Gwendolyn
# p73 Connie Chung'
# p73 Daria Siegel
# p73 Nicole Kolinsky
# p73 Deborah Morris
# p73 Pigeoning
# p73 Connie Chung
# p73 Daria Siegel
# p73 Nicole Kolinsky
# p73 Gwendolyn
# p73 Deborah Morris
# p73 Pigeoning
# p73 christopher wangro
# p73 Stephanie Bleyer
# p73 Pigeoning
# p73 Pigeoning
# p73 Robin Frohardt
# p73 Considerthis
# p75 Gwendolyn
# To:"Connie Chung"
# p75 Jarrod Grim
#
# p75 Nicole Kolinsky
# p75 Daria Siegel
#
# p75 Fred Sham
# p75 Alison Baumann
# p75 Jarrod Grim
# p75 Nicole Kolinsky
# p75 Daria Siegel
# p75 Gwendolyn
# p75 Fred Sham
# p75 Alison Baumann
# p75 Jarrod Grim
# p75 Nicole Kolinsky
# p75 Connie Chung
#
# p75 Daria Siegel
# p75 Gwendolyn
# p75 Fred Sham
# p75 Alison Baumann
# p75 Nicole Kolinsky
# p75 Connie Chung
# p75 Daria Siegel
# p75 Gwendolyn
# p75 Fred Sham
# p75 Jarrod Grim
# p75 Alison Baumann
#
# p75 Daria Siegel
# p75 Connie Chung
# p75 Nicole Kolinsky
# p75 Gwendolyn
# p75 Fred Sham
# p75 Jarrod Grim
# p75 Alison Baumann
#
# p76 QQEU
# p76 d""OUIPO
# p77 Gwendolyn
# To:"Nicole Kolinsky
# p77 Nicole Kolinsky
# p77 Gwendolyn
# p77 Jeremy Soffin
# p77 Nicole
# p78 Gwendolyn
# To:"Connie Chung"
# p78 Daria Siegel
#
# p78 Nicole Kolinsky
# p78 Fred Sham
# p78 Jarrod Grim
#
# p78 Alison Baumann
# p78 Connie Chung
# p78 Daria Siegel
# p78 Nicole Kolinsky
# p78 Gwendolyn
# p78 Fred Sham
# p78 Jarrod Grim
# p78 Alison Baumann
#
# p78 Daria Siegel
# p78 Connie Chung
# p78 Nicole Kolinsky
# p78 Gwendolyn
# p78 Fred Sham
# p78 Jarrod Grim
# p78 Alison Baumann
#
# p79 Gwendolyn
# To:"Nicole Kolinsky
# p79 Nicole Kolinsky
# p79 Gwendolyn
# p79 Nicole Kolinsky
# p79 Gwendolyn
# p79 Jeremy Soffin
# p79 Nicole
# p80 Gwendolyn
# To:"Connie Chung"
# p80 Jarrod Grim
#
# p80 Nicole Kolinsky
# p80 Daria Siegel
#
# p80 Fred Sham
# p80 Alison Baumann
# p80 Connie Chung
# p80 Jarrod Grim
# p80 Nicole Kolinsky
# p80 Daria Siegel
# p80 Gwendolyn
# p80 Fred Sham
# p80 Alison Baumann
# p80 Jarrod Grim
# p80 Nicole Kolinsky
# p80 Connie Chung
#
# p80 Daria Siegel
# p80 Gwendolyn
# p80 Fred Sham
# p80 Alison Baumann
# p80 Nicole Kolinsky
# p80 Connie Chung
# p80 Daria Siegel
# p80 Gwendolyn
# p80 Fred Sham
# p80 Jarrod Grim
# p80 Alison Baumann
#
# p80 Daria Siegel
# p81 Connie Chung
# p81 Nicole Kolinsky
# p81 Gwendolyn
# p81 Fred Sham
# p81 Jarrod Grim
# p81 Alison Baumann
#
# p82 Gwendolyn
# To:"Nicole Kolinsky
# p82 Nicole Kolinsky
# p82 Gwendolyn
# p82 |
# p83 Gwendolyn
# p83 Morris
# p83 Deborah
# p83 Morris
# p83 Deborah
# p83 Gwendolyn
# p83 Pryce
# p83 Leon
# p83 Valerie
# p83 Vazquez
# p83 Raquel
# p83 Wang
# p83 Lauren
# p83 Morris
# p83 Deborah
# p83 Wurwarg
# p83 Jessica
# p83 Greenstein
# p83 Elizabeth
# p83 Briones
# p83 Veach
# p83 Jonathan
# p83 Haddix
# p83 Lindsay
# p83 Pryce
# p83 Tiffany
# p83 Leora
# p83 Elizabeth
# p83 Osgood
# p83 Emily
# p83 Ma Alnisha Gregory
# p83 Chan
# p83 Connie
# p83 Jessica Pavone'
# p83 Sarah Meier-Nelson
# p83 Jessica
# p83 Smith
# p83 Meghan
# p83 Greenstein
# p83 Elizabeth
# p83 Alison Novak
# p84 Susan Wright IBI Group
# p84 Samton
# p84 Arianna Rosenberg
# p84 Liz Eisenberg
# p84 Amy Boyle
# p84 Zineb Morabet
# p84 Desiree Fisher
# p84 Amie Gross
# p84 Deborah VanAmerongen Nixon Peabody
# p84 Cynthia Lewis
# p84 Lois B. Bernstein Gina L
# p84 Rivera Bolden-Rivera & Associates
# p84 Phyllis Ann Santry
# p84 Esq
# p84 Caroline Harris
# p84 Anne Carson
# p84 Elaine Braithwaite
# p84 Dwan Daniels
# p84 Karen Hu
# p84 Liz Oakley
# p84 Kathleen Parisi Hudson
# p84 Nancy Solomon
# p84 Karon Tilley
# p84 Winslow
# p85 Steiner NYC
# p85 Barbara Gratz
# p86 Gwendolyn
# To:"Connie Chung"
#
# p86 Morris
# p86 Deborah
# p86 Connie Chung
# p97 de 20001
# p98 Gwendolyn
# To:"Nicole Kolinsky
# p98 Nicole Kolinsky
# p98 Gwendolyn
# p98 Gwendolyn
# p98 Nicole Kolinsky
# p98 Nicole Kolinsky
# p98 Gwendolyn
# p98 Connie Chung'
# p98 Deborah Morris
#
# p98 Gwendolyn
# p98 Nicole Kolinsky
# p98 Connie Chung'
# p98 Deborah Morris
#
# p98 Nicole Kolinsky
# p98 Connie Chung'
# p98 Gwendolyn
# p98 Deborah Morris
# p98 Emily Walsh
# p98 Nicole Kolinsky
# p98 Emma Woods
# p98 Taylor Maxwell
# p99 Emily Walsh
# p99 sweetgreen
# p99 sweetgreen
# p99 Emily Walsh
# p100 sweetgreen nomad bari

# %% [markdown]
# Really we want a list of _names_ not pages, right?

# %%
list_of_names = {}

with open(jsonl_file, 'r') as f:
    for line in f:
        line = json.loads(line)
        text = line["_source"]["content"]
        page_number = line["_id"]
        doc = nlp(text)
        
        # loop through the entities in the page
        for ent in doc.ents:
            
            # is the entity is a person ...
            if (ent.label_ == "PERSON"):
                
                # check if we already have this entity
                if ent.text in list_of_names:
                    
                    # add this page to the entity's list of pages
                    list_of_names[ent.text] += " " + page_number
                    
                else:
                    
                    # otheriwise start a list of pages
                    list_of_names[ent.text] = page_number

# %%
list_of_names
# Out:
# {'/#&16)16\'85)H76)+"*6)"\')"*1)8&,8,1\'%)+#$$)(,6)!,0\')\'4\'()!$,1\')6': 'p24',
#  "4)#-+(!-,!,>>+6!$,&!)#!+?*9&/'8+!,#!-.+!#+?-!:.)/+!,>!-.+!@ABCDE!*)5:)'%#!-,:)//!F)$,6!(+!G9)/',7/!:6+HI": 'p20',
#  '4)%/\'&"#0E,+$I\'H#4\'J/04)$I\'0+&/$\'#$6\'+,"/0&\'K&+B/\'0/4#,/6\',+\'(#0$/0I\'&+B/\'+,"/0\')&&G/&\',++L\'#$6\'$+,\'/$+G': 'p67',
#  '4,-(&)"(#/0)&(4/+"5': 'p32',
#  '48"-5I\n': 'p32',
#  'Adam Dickter': 'p33',
#  'Adams': 'p13 p13 p13 p14 p14 p14 p14 p14 p15 p15 p15 p15 p15 p18 p18 p18 p18 p18 p19 p19 p19 p19 p20 p32 p32 p32 p32 p32 p32',
#  'Alexandra': 'p59 p65',
#  'Alexandra Jonathan Rosen': 'p65',
#  'Alicia': 'p53',
#  'Alicia glen"s': 'p58',
#  "Alicia glen's": 'p58 p58',
#  'Alison Baumann': 'p75 p75 p75 p78 p80 p80 p80',
#  'Alison Baumann\n': 'p75 p75 p78 p78 p80 p81',
#  'Alison Novak': 'p83 p87',
#  'Amie Gross': 'p84',
#  'Amy Boyle': 'p84 p88',
#  'Andrew Brent': 'p58',
#  'Andrew Cuomo': 'p8 p38',
#  'Ann-Asch': 'p34',
#  'Anna\n': 'p58 p58',
#  'Anne Carson': 'p84 p88',
#  'Anthony Marx': 'p39',
#  'Arianna Rosenberg': 'p84 p88',
#  'Arnie Gross': 'p88',
#  'Ashley Thompson': 'p47',
#  'B. PogrebinMichael': 'p35',
#  'Barbara Gratz': 'p85',
#  'Ben': 'p26 p26 p30 p30 p53',
#  'Ben Furnas': 'p41 p53',
#  'Ben Wyskida': 'p26 p26 p30 p30',
#  'BergerLoren BevansMartin I. BreslerKenneth': 'p34',
#  'BerlinRosen': 'p1',
#  'Betty Liu': 'p4',
#  'Bill': 'p56 p56',
#  "Bill De Blasia's": 'p4',
#  'Bill de Blasia': 'p8 p8',
#  'Bill de Blasio': 'p4 p11 p12 p33',
#  'Bill de BlasioÕs': 'p37',
#  'Blasia': 'p6',
#  'Bratton': 'p51',
#  'Briones': 'p83 p86',
#  'Brodsky': 'p10',
#  'Burton VisotzkyPeter Weiss': 'p35',
#  'Butexpanding': 'p38',
#  'CCRB': 'p59 p65',
#  'CRAIN': 'p8 p8',
#  'Camara': 'p11',
#  'Carol Gerstl': 'p22',
#  'Caroline Harris': 'p84 p88',
#  'Cc': 'p92',
#  'Chan': 'p83 p86',
#  'Chloe': 'p26 p30',
#  'Chloe Hatch': 'p30',
#  'Cmsr': 'p47',
#  'Commlmity Pruinerships': 'p30',
#  'Connie': 'p83 p86',
#  'Connie Chung': 'p71 p71 p71 p73 p75 p75 p78 p78 p80 p80 p81 p86 p86 p92',
#  'Connie Chung\n': 'p71 p75 p80',
#  "Connie Chung'": 'p73 p73 p95 p95 p95 p98 p98 p98',
#  'Considerthis': 'p73',
#  'Cuomo': 'p8 p9 p9 p9 p9 p9 p10 p10 p10 p11 p22 p23 p23 p38 p49 p49',
#  'Cuomo pre-k\n': 'p22 p22',
#  'Cynthia Lewis': 'p84 p88',
#  'DYCD': 'p30',
#  'Dan': 'p47',
#  'Dan Levitan': 'p47 p47 p47 p49 p69',
#  'Dan Levitan\n': 'p49',
#  'Daria Siegel': 'p71 p71 p71 p73 p73 p73 p75 p75 p75 p75 p78 p78 p80 p80 p80 p80 p91 p92 p92',
#  'Daria Siegel\n': 'p71 p75 p78 p80 p91 p92',
#  "Daria Siegel'": 'p91 p91 p92',
#  'David Sirota': 'p44 p45',
#  'De Blasia': 'p4',
#  "De Blasia's": 'p4',
#  'De Blasio': 'p11 p37 p38 p38',
#  'DeBlasio': 'p4 p4',
#  'DeBlasio Clips': 'p4',
#  'Dean Fuleihan': 'p10 p14',
#  'Dean Fuleihan\n': 'p11',
#  'Dean Skelos': 'p6 p11',
#  'Deborah': 'p83 p83 p83 p86 p86 p86 p86 p86',
#  'Deborah\nMorrisSubject': 'p73',
#  'Deborah Morris': 'p73 p73 p73 p95 p95 p95 p98',
#  'Deborah Morris\n': 'p98 p98',
#  'Deborah VanAmerongen Nixon Peabody': 'p84 p88',
#  'Desiree Fisher': 'p84 p88',
#  'Devon Puglia': 'p39',
#  'Dwan Daniels': 'p84',
#  'E"55)"K\'F$17': 'p24',
#  'Elaine Braithwaite': 'p84 p88',
#  'Eliza Shapiro\n': 'p37',
#  'Elizabeth': 'p83 p83 p83 p86 p86 p87',
#  'Emanuel AxPeter': 'p34',
#  'Emily': 'p83 p86',
#  'Emily Walsh': 'p95 p95 p95 p98 p99 p99',
#  'Emma': 'p8 p14 p14 p15 p15 p15 p18 p19 p19 p23 p44 p45 p49',
#  'Emma\n': 'p11 p13 p22 p22 p32 p37 p46 p46 p67',
#  'Emma Cc': 'p14 p14 p14 p14 p15 p15 p18 p18 p19 p19',
#  'Emma Walzak': 'p14',
#  'Emma Wolf': 'p14',
#  'Emma Wolfe': 'p6 p49',
#  'Emma Woods': 'p16 p20 p23 p47 p47 p49 p95 p98',
#  'Emmaá Adams Marti Cc': 'p19',
#  'Espinal': 'p51',
#  'Esq': 'p84 p88',
#  'Felicia SolAlisa': 'p35',
#  'Fred Sham': 'p75 p75 p75 p75 p75 p78 p78 p78 p80 p80 p80 p80 p81',
#  'GWEN LITVAK': 'p90',
#  'Gabriel\n': 'p46',
#  "George Arzt's": 'p8',
#  'Gladys CruTion': 'p47',
#  'Greenstein': 'p83 p83 p86 p87',
#  'GreenwaldJane HirschmannErica Jong': 'p34',
#  'Gregory': 'p86',
#  'Gwendolyn': 'p71 p71 p71 p71 p73 p73 p73 p73 p75 p75 p75 p75 p77 p78 p78 p79 p79 p80 p80 p80 p81 p82 p83 p83 p86 p86 p86 p90 p91 p91 p91 p91 p91 p91 p92 p92 p92 p94 p94 p95 p95 p95 p95 p98 p98 p98 p98 p98',
#  'Gwendolyn\nTo:"Connie Chung"': 'p75 p78 p80',
#  'Gwendolyn\nTo:"Connie Chung"\n': 'p86',
#  'Gwendolyn\nTo:"Nicole Kolinsky': 'p77 p79 p82 p94 p98',
#  'Gwyneth Paltrow': 'p3',
#  'H*!4.1!.3G!$%-!8.1!0': 'p43',
#  'H<).#4#(.)ILD)6"\')*H#$#6<)&*#1\')&\'4\'(7\')/&,0)6"\')+\'*$6"#\'16)I\'+)L,&-\'&1)*1)*)16*H$\')/7(%': 'p24',
#  'Haddix': 'p83 p86',
#  'Hank Sheinkopf': 'p8',
#  'Harvey Weinstein': 'p3',
#  'Hatch': 'p26 p30 p41',
#  'Hawkins': 'p8',
#  'Heather Briccetti': 'p9',
#  'Henry Goldman': 'p3 p3',
#  'J"\'&\'/,&\')#6N1),H4#,71)6"*6\n': 'p24',
#  'JP Jon paul': 'p47',
#  'James Patchett': 'p58',
#  'Janet': 'p51',
#  'Janua': 'p14 p14 p18 p18 p23',
#  'Jarrod Grim': 'p75 p75 p75 p75 p78 p78 p80 p80 p80 p81',
#  'Jarrod Grim\n': 'p75 p78 p80',
#  'Jason Chiusano': 'p71 p71 p72',
#  'Javier H. Valdes': 'p23',
#  'Jeffrey Klein': 'p6 p9 p11',
#  'Jennifer': 'p15',
#  'Jennifer\n': 'p16 p20',
#  'Jennifer \n': 'p13 p20',
#  'Jeremy Soffin': 'p77 p79',
#  'Jessica': 'p83 p83 p86 p86',
#  "Jessica Pavone'": 'p83 p86',
#  'Jill Krauss': 'p47 p47',
#  'Jimmy Pan': 'p2',
#  'John Kanas': 'p4',
#  'Jon Paul': 'p47',
#  'Jon Paul Subject': 'p47',
#  'Jonathan': 'p41 p41 p53 p54 p59 p65 p83 p86',
#  'Jonathan Rosen': 'p1 p4 p4 p8 p11 p15 p15 p19 p19 p23 p26 p26 p30 p30 p30 p32 p32 p37 p37 p41 p41 p42 p42 p42 p43 p43 p44 p44 p44 p45 p45 p45 p47 p47 p47 p50 p53 p53 p54 p54 p55 p55 p56 p58 p58 p59 p65 p65',
#  'Jonathan Rosen\n': 'p49 p58',
#  'Jonathan Rosen BerlinRosen': 'p56',
#  'Jonathan Rosen Stanton': 'p59',
#  'Jonathan Rosen" RE': 'p45',
#  "Jonathan Rosen'": 'p14 p14 p14 p18 p18 p18 p18 p19 p19',
#  "Jonathan Rosen'á": 'p15',
#  'Jonathan Rosen.----PhiiWalzak': 'p45',
#  'Jonathan Westin': 'p46',
#  "Jonathan Westin'": 'p46',
#  'Josh Gold': 'p23 p47 p47 p49',
#  'Josh Gold\n': 'p49',
#  'Josh R Kate Taylor': 'p47',
#  'Josh Wallack': 'p47 p47 p47',
#  'KEN LOVETT': 'p49',
#  'Karen Hu': 'p84 p88',
#  'Karim Camara': 'p11',
#  'Karon Tilley': 'p84',
#  'Karon Tilley Steiner': 'p88',
#  'Kate Rubin': 'p59 p65',
#  'Kate Taylor': 'p47 p47 p47',
#  'Katherine': 'p51 p51 p51 p51',
#  'Kathleen Parisi Hudson': 'p84 p88',
#  'Katz': 'p68 p68 p68 p69 p69 p69 p69',
#  'Kelly': 'p86',
#  'Ken Lovett': 'p11',
#  'Kenneth Lovett http://www.nydailynews.com/new-york/rejecti ng-nyc': 'p6',
#  'Klein': 'p6 p6 p6 p6 p6 p68 p69',
#  'Lama Santucci': 'p65',
#  'Laura Santucci': 'p60',
#  'Lauren': 'p83 p86',
#  'LeighAlan H. LevineRabbi': 'p35',
#  'Leon': 'p83 p86',
#  'Leora': 'p83 p86',
#  'Lindsay': 'p51 p83 p86',
#  'LitVak': 'p95',
#  'Liz Eisenberg': 'p84 p88',
#  'Liz Oakley': 'p84 p88',
#  'Lois B. Bernstein Gina L': 'p84 p88',
#  'Lupo': 'p47',
#  'MAIG': 'p14 p14',
#  'Ma Alnisha Gregory': 'p83',
#  'Mama Saul': 'p69',
#  'Marti': 'p13 p13 p13 p14 p14 p14 p15 p15 p15 p18 p18 p18 p18 p18 p18 p19 p19 p19 p20 p32 p32 p32 p32 p32 p32',
#  'Marti Cc': 'p15 p15 p19',
#  'Marx': 'p39',
#  'Matt': 'p47',
#  'Matt Tepoer': 'p47',
#  'Matt Tepper': 'p47 p51 p51 p51',
#  'Matt Tepper<matt@berlinrosen.com': 'p47',
#  'Mayor de Blasia': 'p23 p23',
#  "Mayor de Blasia's": 'p6 p6',
#  'Mayor de Blasio': 'p49',
#  "Mayor de Blasio's": 'p11',
#  'Meghan': 'p83 p86',
#  'Message-----From': 'p44 p45',
#  'Michael': 'p68 p68 p69 p69',
#  'Mike Rabinowitz': 'p23 p47 p47',
#  'Mike Rabinowitz\n': 'p49',
#  'Monica': 'p6',
#  'Monica\n': 'p68 p69',
#  'Morris': 'p83 p83 p83 p86 p86 p86 p86 p86 p86',
#  'Nancy Solomon': 'p84 p88',
#  'Nancy Wackstein': 'p38',
#  'Nelson': 'p86',
#  'Nicholas A. CotzArtistic': 'p72',
#  'Nick Cotz': 'p71',
#  'Nicole': 'p71 p77 p79 p91',
#  'Nicole\n ': 'p71',
#  'Nicole Kolinsky': 'p72 p73 p73 p73 p73 p75 p75 p75 p75 p75 p77 p78 p78 p78 p79 p79 p80 p80 p80 p80 p81 p82 p91 p91 p91 p91 p92 p92 p92 p94 p94 p95 p95 p95 p95 p95 p98 p98 p98 p98 p98 p98',
#  'Norvell': 'p32 p32 p67',
#  'Osgood': 'p83 p86',
#  'Oskar': 'p31',
#  'Oskar ruáe': 'p26',
#  'Paul': 'p58 p58',
#  'Pedro Noguera': 'p37 p38',
#  'Peter': 'p4 p8 p30 p30 p41 p53',
#  'Peter\n': 'p11',
#  'Peter A. JosephAlice Kessler-Harris\n': 'p35',
#  'Peter FW': 'p26',
#  'Peter R': 'p14 p14 p15',
#  'Peter Ragon': 'p19',
#  'Peter Ragone': 'p47 p47',
#  'Peter Ragone Cc': 'p4',
#  'PhiiWalzak': 'p47',
#  'Phil': 'p14 p14 p15 p15 p15 p18 p18 p18 p18 p18 p19 p19 p32 p32',
#  'Phil\n': 'p3 p3 p20 p32',
#  'Phil Re:': 'p14',
#  'Phyllis Ann Santry': 'p84 p88',
#  'Pigeoning': 'p73 p73 p73 p73 p73',
#  'Pis': 'p44 p45 p47',
#  'Poe-Kest': 'p58 p58',
#  'Pryce': 'p83 p83 p86 p86',
#  'QQEU': 'p76',
#  'Quotes Quotes': 'p23',
#  'Rabinowitz': 'p23',
#  'Rachel CowanBarbara': 'p34',
#  'Ragone': 'p4 p4 p8 p11',
#  'Raquel': 'p83 p86',
#  'RatnerAnne': 'p35',
#  'Rebecca': 'p68 p69',
#  'Rebecca Katz': 'p44 p44 p45 p45',
#  'Rebecca [mailto:RKKatz@cityhall.nyc.gov': 'p68',
#  'Richard': 'p72',
#  'Richard Brodsky': 'p8 p10',
#  "Richard Brodsky's": 'p8',
#  'Rivera Bolden-Rivera & Associates': 'p84 p88',
#  'Robin Frohardt': 'p73',
#  'Rosen': 'p32',
#  'Rosen Hatch': 'p53',
#  'Ross': 'p4',
#  'Ruchi': 'p71 p71 p71 p71 p71',
#  'Ruth J. AbramKaren R. AdlerArlene AldaAnita': 'p34',
#  'Samton': 'p84 p88',
#  'Santucci': 'p60',
#  'Sarah': 'p86',
#  'Sarah Meier-Nelson': 'p83',
#  'Sarah Weiss': 'p88',
#  'Saul': 'p68 p68 p69 p69',
#  'Sharon KleinbaumGil': 'p35',
#  'Sheldon\n': 'p9',
#  'Sherif Soliman': 'p47 p47',
#  'Silver': 'p10',
#  'Sirota': 'p44 p45',
#  'Skelos': 'p6 p11 p11',
#  'Smith': 'p83 p86',
#  'Stanton': 'p65 p65',
#  'SteinemHerbert': 'p35',
#  'Steiner NYC': 'p85',
#  'Stephanie Bleyer': 'p73',
#  'Steve Schwarzman': 'p5',
#  'Susan Wright': 'p87',
#  'Susan Wright IBI Group': 'p84',
#  'Taylor Maxwell': 'p95 p98',
#  'Tiffany': 'p83 p86',
#  'To:"Matt Tepper': 'p51',
#  'Unger': 'p51 p51 p51 p51',
#  'Valerie': 'p83 p86',
#  'Vazquez': 'p83 p86',
#  'Veach': 'p83 p86',
#  'Vincent Alvarez': 'p9',
#  'Wa za': 'p18',
#  'Wackstein': 'p39',
#  'Walzak': 'p15',
#  'Wang': 'p83 p86',
#  'Wi': 'p47',
#  'Wilbur Ross': 'p5',
#  'WileyJNorvell': 'p47 p47',
#  'Winslow': 'p84 p88',
#  'Wolfe': 'p8 p11 p13 p13 p14 p14 p14 p14 p14 p15 p15 p15 p15 p18 p18 p18 p18 p18 p19 p19 p19 p19 p20 p22 p22 p22 p23 p23 p32 p37 p44 p44 p45 p45 p45 p45 p46 p46 p46 p67',
#  'Wurwarg': 'p83 p86',
#  'Y00*):,,%1': 'p24',
#  'Zineb Morabet': 'p84 p88',
#  'beyootiful': 'p18',
#  'christopher wangro': 'p73',
#  'd""OUIPO': 'p76',
#  'de 20001': 'p97',
#  'de Blasia': 'p14',
#  "de Blasia's": 'p6',
#  'de Blasio': 'p9 p9 p9 p9 p9 p9 p9 p9 p9 p10 p10 p10 p10 p38',
#  'de BlasioÕs': 'p38',
#  'gmail': 'p44 p45',
#  'gmaill': 'p47',
#  'h\niking the city income tax on': 'p6',
#  'iiiiiliiiiiilii': 'p15',
#  'ike Rabinowitz': 'p47',
#  'josh wallach': 'p47',
#  'lllll': 'p23',
#  'loor': 'p6',
#  'mailto': 'p3 p42 p42 p43 p51 p51 p69 p95',
#  'mulgrew': 'p22',
#  'njoying': 'p41',
#  'oney': 'p4',
#  'pre-K': 'p9 p9 p9 p9 p9',
#  'slhe': 'p26',
#  'sweetgreen': 'p95 p95 p99 p99',
#  'sweetgreen nomad bari': 'p100',
#  'this ty': 'p18',
#  'wou mar a': 'p65',
#  'xact': 'p47',
#  '|  ': 'p82',
#  '|  nyc.gov/planyc+': 'p90',
#  'Òwe': 'p49'}

# %%
for name, pages in sorted(list_of_names.items()):
    print(name, "(" + pages + ")" )
# Out:
# /#&16)16'85)H76)+"*6)"')"*1)8&,8,1'%)+#$$)(,6)!,0')'4'()!$,1')6 (p24)
# 4)#-+(!-,!,>>+6!$,&!)#!+?*9&/'8+!,#!-.+!#+?-!:.)/+!,>!-.+!@ABCDE!*)5:)'%#!-,:)//!F)$,6!(+!G9)/',7/!:6+HI (p20)
# 4)%/'&"#0E,+$I'H#4'J/04)$I'0+&/$'#$6'+,"/0&'K&+B/'0/4#,/6',+'(#0$/0I'&+B/'+,"/0')&&G/&',++L'#$6'$+,'/$+G (p67)
# 4,-(&)"(#/0)&(4/+"5 (p32)
# 48"-5I
#  (p32)
# Adam Dickter (p33)
# Adams (p13 p13 p13 p14 p14 p14 p14 p14 p15 p15 p15 p15 p15 p18 p18 p18 p18 p18 p19 p19 p19 p19 p20 p32 p32 p32 p32 p32 p32)
# Alexandra (p59 p65)
# Alexandra Jonathan Rosen (p65)
# Alicia (p53)
# Alicia glen"s (p58)
# Alicia glen's (p58 p58)
# Alison Baumann (p75 p75 p75 p78 p80 p80 p80)
# Alison Baumann
#  (p75 p75 p78 p78 p80 p81)
# Alison Novak (p83 p87)
# Amie Gross (p84)
# Amy Boyle (p84 p88)
p15 p15 p15 p18 p18 p18 p18 p18 p19 p19 p32 p32)
# Phil
#  (p3 p3 p20 p32)
# Phil Re: (p14)
# Phyllis Ann Santry (p84 p88)
# Pigeoning (p73 p73 p73 p73 p73)
# Pis (p44 p45 p47)
# Poe-Kest (p58 p58)
# Pryce (p83 p83 p86 p86)
# QQEU (p76)
# Quotes Quotes (p23)
# Rabinowitz (p23)
# Rachel CowanBarbara (p34)
# Ragone (p4 p4 p8 p11)
# Raquel (p83 p86)
# RatnerAnne (p35)
# Rebecca (p68 p69)
# Rebecca Katz (p44 p44 p45 p45)
# Rebecca [mailto:RKKatz@cityhall.nyc.gov (p68)
# Richard (p72)
# Richard Brodsky (p8 p10)
# Richard Brodsky's (p8)
# Rivera Bolden-Rivera & Associates (p84 p88)
# Robin Frohardt (p73)
# Rosen (p32)
# Rosen Hatch (p53)
# Ross (p4)
# Ruchi (p71 p71 p71 p71 p71)
# Ruth J. AbramKaren R. AdlerArlene AldaAnita (p34)
# Samton (p84 p88)
# Santucci (p60)
# Sarah (p86)
# Sarah Meier-Nelson (p83)
# Sarah Weiss (p88)
# Saul (p68 p68 p69 p69)
# Sharon KleinbaumGil (p35)
# Sheldon
#  (p9)
# Sherif Soliman (p47 p47)
# Silver (p10)
# Sirota (p44 p45)
# Skelos (p6 p11 p11)
# Smith (p83 p86)
# Stanton (p65 p65)
# SteinemHerbert (p35)
# Steiner NYC (p85)
# Stephanie Bleyer (p73)
# Steve Schwarzman (p5)
# Susan Wright (p87)
# Susan Wright IBI Group (p84)
# Taylor Maxwell (p95 p98)
# Tiffany (p83 p86)
# To:"Matt Tepper (p51)
# Unger (p51 p51 p51 p51)
# Valerie (p83 p86)
# Vazquez (p83 p86)
# Veach (p83 p86)
# Vincent Alvarez (p9)
# Wa za (p18)
# Wackstein (p39)
# Walzak (p15)
# Wang (p83 p86)
# Wi (p47)
# Wilbur Ross (p5)
# WileyJNorvell (p47 p47)
# Winslow (p84 p88)
# Wolfe (p8 p11 p13 p13 p14 p14 p14 p14 p14 p15 p15 p15 p15 p18 p18 p18 p18 p18 p19 p19 p19 p19 p20 p22 p22 p22 p23 p23 p32 p37 p44 p44 p45 p45 p45 p45 p46 p46 p46 p67)
# Wurwarg (p83 p86)
# Y00*):,,%1 (p24)
# Zineb Morabet (p84 p88)
# beyootiful (p18)
# christopher wangro (p73)
# d""OUIPO (p76)
# de 20001 (p97)
# de Blasia (p14)
# de Blasia's (p6)
# de Blasio (p9 p9 p9 p9 p9 p9 p9 p9 p9 p10 p10 p10 p10 p38)
# de BlasioÕs (p38)
# gmail (p44 p45)
# gmaill (p47)
# h
# iking the city income tax on (p6)
# iiiiiliiiiiilii (p15)
# ike Rabinowitz (p47)
# josh wallach (p47)
# lllll (p23)
# loor (p6)
# mailto (p3 p42 p42 p43 p51 p51 p69 p95)
# mulgrew (p22)
# njoying (p41)
# oney (p4)
# pre-K (p9 p9 p9 p9 p9)
# slhe (p26)
# sweetgreen (p95 p95 p99 p99)
# sweetgreen nomad bari (p100)
# this ty (p18)
# wou mar a (p65)
# xact (p47)
# |   (p82)
# |  nyc.gov/planyc+ (p90)
# Òwe (p49)

# %% [markdown]
# Once you know a name is _there_ then you can search for it [in the original document](https://qz-aistudio-public.s3.amazonaws.com/workshops/2018.05.24_BerlinRosen_Responsive_Records_100pgs.pdf).
