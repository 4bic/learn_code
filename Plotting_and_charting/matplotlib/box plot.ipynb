# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
normal_sample = np.random.normal(loc=0.0, scale=1.0, size=10000)
random_sample = np.random.random(size=10000)
gamma_sample = np.random.gamma(2, size=10000)

df = pd.DataFrame({'normal': normal_sample,
                  'random': random_sample,
                  'gamma': gamma_sample})

df.describe()
# Out:
#               gamma        normal        random
# count  10000.000000  10000.000000  10000.000000
# mean       1.986306      0.013702      0.502120
# std        1.399332      0.999048      0.290724
# min        0.013692     -3.649772      0.000026
# 25%        0.956508     -0.669969      0.249645
# 50%        1.670168      0.009979      0.503524
# 75%        2.670794      0.685520      0.756156
# max       11.548994      4.076340      0.999924

# %%
# box and whisker plots
plt.figure()
_ = plt.boxplot(df['normal'], whis='range')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# add the rest of details
plt.clf()
_ = plt.boxplot([df['normal'], df['random'], df['gamma']], whis='range')

# %%
# distribution plot layered on box plot
import mpl_toolkits.axes_grid1.inset_locator as mp1_il

plt.figure()
plt.boxplot([df['normal'], df['random'], df['gamma']], whis='range')
ax2 = mp1_il.inset_axes(plt.gca(), width='60%', height='40%', loc=2)
ax2.hist(df['gamma'], bins=100)
ax2.margins(x=0.5)
ax2.title.set_text('distribution plot layered on box plot')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# adjust axis of histogram
ax2.yaxis.tick_right()

# %%
# detecting outliers
plt.figure()
plt.boxplot([df['normal'], df['random'], df['gamma']])
# Out:
# <img src="data:image/png;base64,..." width="640">
# {'boxes': [<matplotlib.lines.Line2D at 0x11c000e10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x11ac6c208>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x11c054c50>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11c054438>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x11c000d30>,
# ...
#   <matplotlib.lines.Line2D at 0x11c074e10>]}

# %%
plt.boxplot?
