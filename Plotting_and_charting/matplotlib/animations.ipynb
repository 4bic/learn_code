# %% [markdown]
# ## Plot Animation

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 
import matplotlib.animation as animation

# %%
n = 100
x = np.random.randn(n)

# %%
def update(curr):
    if curr == n:
        a.event_source.stop()
    plt.cla()
    bins = np.arange(-4, 4, 0.5)
    plt.hist(x[:curr], bins=bins)
    plt.axis([-4,4,0,30])
    plt.gca().set_title('Sample the Normal Didtribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    plt.annotate('n={}'.format(curr), [3,27])

# %%
# generate constructor
fig = plt.figure()
a = animation.FuncAnimation(fig, update, interval=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Interactivity

# %%
plt.figure()
data = np.random.rand(10)
plt.plot(data)

def onclick(event):
    plt.cla()
    plt.plot(data)
    plt.gca().set_title('Event at Pixel{},{} and data {},{}'.format(event.x,
                                                                   event.y,
                                                                   '\n',
                                                                   event.xdata,
                                                                   event.ydata))
plt.gcf().canvas.mpl_connect('button_press_event', onclick)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 8

# %% [markdown]
# ## Pick Event

# %%
from random import shuffle
origins = ['Egypt', 'India', 'Kenya', 'Congo', 'South Africa',
           'Namibia', 'Ghana', 'Liberia', 'Morocco', 'Tanzania']
shuffle(origins)

df = pd.DataFrame({'height': np.random.rand(10),
                   'weight': np.random.rand(10),
                   'origin': origins })
df
# Out:
#      height        origin    weight
# 0  0.457376         Congo  0.485342
# 1  0.807860       Morocco  0.535303
# 2  0.656368         Kenya  0.472097
# 3  0.451741  South Africa  0.052953
# 4  0.091399         Egypt  0.818721
# 5  0.336522       Namibia  0.454829
# 6  0.496160      Tanzania  0.594160
# 7  0.999252       Liberia  0.027209
# 8  0.018651         Ghana  0.338582
# 9  0.169345         India  0.738400

# %%
plt.figure()
plt.scatter(df['height'], df['weight'], picker=5)
plt.gca().set_ylabel('Weight')
plt.gca().set_xlabel('Height')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,0,'Height')

# %%
def onpick(event):
    origin = df.iloc[event.ind[0]]['origin']
    plt.gca().set_title('Selected item comes from {}'.format(origin))
    
plt.gcf().canvas.mpl_connect('pick_event', onpick)
# Out:
# 8
