# %%
# %matplotlib notebook

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Generate sample data

# %%
np.random.seed(1234)

# Series of normal distribution of (1000) mean(0) sd(10)
v1 = pd.Series(np.random.normal(0,10,1000), name='v1')
v2 = pd.Series(2*v1 + np.random.normal(60,15,1000), name='v2')

# %% [markdown]
# ### Plot Histogram

# %%
plt.figure()
plt.hist(v1, alpha=0.7, bins=np.arange(-50,150,5), label='v1');
plt.hist(v2, alpha=0.7, bins=np.arange(-50,150,5), label='v2');
plt.legend();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Kernel density plot over stacked histogram

# %%
plt.figure()
plt.hist([v1, v2], histtype='barstacked', normed=True);
# combine v1 & v2
v3 = np.concatenate((v1,v2))
sns.kdeplot(v3); #plot the probability density funtion of V3
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/4bic/anaconda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# ### Combined distribution plots

# %%
plt.figure()
sns.distplot(v3, hist_kws={'color': 'Teal'}, kde_kws={'color': 'Navy'})
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/4bic/anaconda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# ### Joint plots
#
# Allows for viewing of distribution of variables individualy

# %%
sns.jointplot(v1, v2, alpha=0.4);
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## Seaborn tweaks on plotting

# %%
grid = sns.jointplot(v1, v2, alpha=0.4);
grid.ax_joint.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# #### Use Hexagon markers

# %%
sns.jointplot(v1, v2,kind='hex');
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### Heat map

# %%
sns.set_style('white')

sns.jointplot(v1, v2,kind='kde', space=0);
# Out:
# <img src="data:image/png;base64,..." width="600">
# /Users/4bic/anaconda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# ### Handling of categorical data
#
# load Iris data

# %%
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# ### Scatter plot Matrix

# %%
sns.pairplot(iris, hue='Name', diag_kind='kde')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# /Users/4bic/anaconda/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# ### Violin Plot
#
# A more informative version of box plot

# %%
plt.figure(figsize=(12,8))
plt.subplot(121)
sns.swarmplot('Name', 'PetalLength', data=iris)
plt.subplot(122)
sns.violinplot('Name', 'PetalLength', data=iris)
# Out:
# <img src="data:image/png;base64,..." width="1200">
