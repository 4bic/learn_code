# %%
# %matplotlib notebook
# use "%matplotlib notebook" for interactive notebook
# as instead of earlier "matplotlib inline"

# %%
import matplotlib as mpl
mpl.get_backend()
# Out:
# 'nbAgg'

# %%
import matplotlib.pyplot as plt
plt.plot?

# %%
# easy (x,y) plot
plt.plot(3,2,'.')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

# create new figure
fig = Figure()

# associate fig with the backend
canvas = FigureCanvasAgg(fig)

# add subplot
ax = fig.add_subplot(111)#refers to 1plot
# plot points
ax.plot(3,2,'.')
# save figure to .png file
canvas.print_png('plot_test.png')

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

# create a new figure 
plt.figure()
# plot points
plt.plot(3,2,'o')
# get current axes
ax = plt.gca()
# Set axis properties
ax.axis([0,6,0,10])
# ([xmin, xmax, ymin , ymax])
# canvas.print_png('plot_2.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
# [0, 6, 0, 10]

# %%
plt.plot(1.5, 1.5, 'o')
plt.plot(2, 2, 'o')
plt.plot(2.5, 2.5, 'o')
ax = plt.gca()
ax.get_children()
# Out:
# [<matplotlib.lines.Line2D at 0x116a0fbe0>,
#  <matplotlib.lines.Line2D at 0x1173c72b0>,
#  <matplotlib.lines.Line2D at 0x1173c7d68>,
#  <matplotlib.lines.Line2D at 0x1173c70b8>,
#  <matplotlib.lines.Line2D at 0x118364a20>,
#  <matplotlib.lines.Line2D at 0x118380208>,
#  <matplotlib.lines.Line2D at 0x1183647b8>,
#  <matplotlib.lines.Line2D at 0x118349fd0>,
#  <matplotlib.lines.Line2D at 0x118349a58>,
#  <matplotlib.lines.Line2D at 0x11835aa90>,
#  <matplotlib.spines.Spine at 0x1169a7940>,
#  <matplotlib.spines.Spine at 0x1169a7b38>,
#  <matplotlib.spines.Spine at 0x1169a7d30>,
#  <matplotlib.spines.Spine at 0x1169a7f28>,
#  <matplotlib.axis.XAxis at 0x1169ad128>,
#  <matplotlib.axis.YAxis at 0x1169bc748>,
#  <matplotlib.text.Text at 0x1169e4278>,
#  <matplotlib.text.Text at 0x1169e42e8>,
#  <matplotlib.text.Text at 0x1169e4358>,
#  <matplotlib.patches.Rectangle at 0x1169e4390>]
