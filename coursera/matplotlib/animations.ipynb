# %% [markdown]
# ## Plot Animation

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 
import matplotlib.animation as animation

# %%
n = 100
x = np.random.randn(n)

# %%
def update(curr):
    if curr == n:
        a.event_source.stop()
    plt.cla()
    bins = np.arange(-4, 4, 0.5)
    plt.hist(x[:curr], bins=bins)
    plt.axis([-4,4,0,30])
    plt.gca().set_title('Sample the Normal Didtribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    plt.annotate('n={}'.format(curr), [3,27])

# %%
# generate constructor
fig = plt.figure()
a = animation.FuncAnimation(fig, update, interval=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Interactivity

# %%
plt.figure()
data = np.random.rand(10)
plt.plot(data)

def onclick(event):
    plt.cla()
    plt.plot(data)
    plt.gca().set_title('Event at Pixel{},{} and data {},{}'.format(event.x,
                                                                   event.y,
                                                                   '\n',
                                                                   event.xdata,
                                                                   event.ydata))
plt.gcf().canvas.mpl_connect('button_press_event', onclick)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 7

# %% [markdown]
# ## Pick Event

# %%
from random import shuffle
origins = ['Egypt', 'India', 'Kenya', 'Congo', 'South Africa',
           'Namibia', 'Ghana', 'Liberia', 'Morocco', 'Tanzania']
shuffle(origins)

df = pd.DataFrame({'height': np.random.rand(10),
                   'weight': np.random.rand(10),
                   'origin': origins })
df
# Out:
#      height        origin    weight
# 0  0.941223      Tanzania  0.959429
# 1  0.232396         Kenya  0.539418
# 2  0.595842         Egypt  0.329625
# 3  0.240436       Morocco  0.446200
# 4  0.886697  South Africa  0.415555
# 5  0.696857       Liberia  0.467425
# 6  0.826014         Congo  0.831505
# 7  0.996589       Namibia  0.204004
# 8  0.911538         Ghana  0.736960
# 9  0.837834         India  0.870213

# %%
plt.figure()
plt.scatter(df['height'], df['weight'], picker=5)
plt.gca().set_ylabel('Weight')
plt.gca().set_xlabel('Height')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def onpick(event):
    origin = df.iloc[event.ind[0]]['origin']
    plt.gca().set_title('Selected item comes from {}'.format(origin))
    
plt.gcf().canvas.mpl_connect('pick_event', onpick)
# Out:
# 7
