# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get("http://www.buyrentkenya.com/buy/results?location=Eldoret&filters%5Basking_price%5D%5Belt%5D=")
c = r.content

# %%
soup = BeautifulSoup(c, "html.parser")
check source code of loaded page
#print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <!-- METAS -->
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="BRK" name="author"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="http://www.buyrentkenya.com/property-for-sale-in-eldoret-434,435,436,2680,2668,2669,2670,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2689,2690,2691,2692,2693,2694,2695,2696,2697,2698,2699,2700,2701,2702,2703,2705,2706,2707,2708,2709.html" rel="canonical"/>
#   <link href="http://m.buyrentkenya.com/property-for-sale-in-eldoret-434,435,436,2680,2668,2669,2670,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2689,2690,2691,2692,2693,2694,2695,2696,2697,2698,2699,2700,2701,2702,2703,2705,2706,2707,2708,2709.html" media="only screen and (max-width: 640px)" rel="alternate"/>
#   <meta content="Properties for sale or rent in Eldoret by trusted agencies | BuyRentKenya" name="title"/>
#   <meta content=" Properties For Sale Or Rent In Eldoret on Buyrentkenya.com. Buy Properties In Eldoret. 9 listing(s) available!" name="description"/>
#   <meta content="http://www.buyrentkenya.com/" name="url"/>
#   <meta content="website" name="type"/>
#   <meta content="http://www.buyrentkenya.com/assets/brk/images/logo/256.png" name="image"/>
#   <meta content="website" property="og:type">
#    <meta content="Properties for sale or rent in Eldoret by trusted agencies | BuyRentKenya" property="og:title">
#     <meta content=" Properties for sale or rent in Eldoret on buyrentkenya.com - 9 listing(s) available!" property="og:description">
#      <meta content="http://www.buyrentkenya.com/assets/brk/images/logo/256.png" property="og:image"/>
#      <meta content="image/png" property="og:image:type">
#       <meta content="http://www.buyrentkenya.com/buy/results?filters%5Basking_price%5D%5Belt%5D=&amp;location=Eldoret" property="og:url">
#        <meta content="www.buyrentkenya.com" property="og:site_name">
#         <title>
#          Properties for sale in Eldoret | Buy  Properties in Eldoret
#         </title>
#         <link href="/88cb00e7070fce84c4e6298258d61bde/assets/css/results.all.min.css" rel="stylesheet" type="text/css"/>
#         <link href="/88cb00e7070fce84c4e6298258d61bde/assets/fonts/fonts.stylesheet.min.css" rel="stylesheet" type="text/css"/>
#         <link href="/88cb00e7070fce84c4e6298258d61bde/assets/css/new-products.min.css" rel="stylesheet" type="text/css"/>
#         <style>
#          .container, .navbar-static-top .container, .navbar-fixed-top .container, .navbar-fixed-bottom .container { margin-left: 0px !important; width: 100% !important; max-width: 100% !important; padding:0 55px 20px !important; }
#             .navbar>.container .navbar-brand { margin-left: -12px !important; padding: 0 !important; }
#             #newsletter-check{ float: none !important; }
#         </style>
#         <style>
#          .regional img {
#             margin: 10px;
#             max-width: 400px !important;
#             border: 2px solid #FFFFFF;
#         }
#         </style>
#         <script type="text/javascript">
#          var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         (function() {
#             var gads = document.createElement('script');
#             gads.async = true;
#             gads.type = 'text/javascript';
#             var useSSL = 'https:' == document.location.protocol;
#             gads.src = (useSSL ? 'https:' : 'http:') +
#             '//www.googletagservices.com/tag/js/gpt.js';
#             var node = document.getElementsByTagName('script')[0];
#             node.parentNode.insertBefore(gads, node);
#         })();
#         </script>
#         <script type="text/javascript">
#          googletag.cmd.push(function() {
#
#             var slot1 = googletag.defineSlot('/7108206/BRK_KE_RESULT', [[300, 300], [300, 600]], 'div-gpt-ad-1453817992651-1').setTargeting('slot', ['1']).setTargeting('type', ['buy']).addService(googletag.pubads());
#             var slot2 = googletag.defineSlot('/7108206/BRK_KE_RESULT', [[300, 300], [300, 600]], 'div-gpt-ad-1453817992651-2').setTargeting('slot', ['2']).setTargeting('type', ['buy']).addService(googletag.pubads());
#             var slot3 = googletag.defineSlot('/7108206/BRK_KE_RESULT', [[300, 300], [300, 600]], 'div-gpt-ad-1453817992651-3').setTargeting('slot', ['3']).setTargeting('type', ['buy']).addService(googletag.pubads());
#             var slot4 = googletag.defineSlot('/7108206/BRK_KE_RESULT', [[300, 300], [300, 600]], 'div-gpt-ad-1453817992651-4').setTargeting('slot', ['4']).setTargeting('type', ['buy']).addService(googletag.pubads());
#             var slot5 = googletag.defineSlot('/7108206/BRK_KE_RESULT', [[300, 300], [300, 600]], 'div-gpt-ad-1453817992651-5').setTargeting('slot', ['5']).setTargeting('type', ['buy']).addService(googletag.pubads());
#             var slot6 = googletag.defineSlot('/7108206/BRK_KE_RESULT', [[300, 300], [300, 600]], 'div-gpt-ad-1453817992651-6').setTargeting('slot', ['6']).setTargeting('type', ['buy']).addService(googletag.pubads());
#
#             window.setInterval(function () { googletag.pubads().refresh([slot1]); }, 10000);
#             window.setInterval(function () { googletag.pubads().refresh([slot2]); }, 10000);
#             window.setInterval(function () { googletag.pubads().refresh([slot3]); }, 10000);
#             window.setInterval(function () { googletag.pubads().refresh([slot4]); }, 10000);
#             window.setInterval(function () { googletag.pubads().refresh([slot5]); }, 10000);
#             window.setInterval(function () { googletag.pubads().refresh([slot6]); }, 10000);
#
#             googletag.pubads().enableSingleRequest();
#             googletag.enableServices();
#
#         });
#         </script>
#         <!-- Facebook Pixel Code -->
#         <script>
#          !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#                 n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#             n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#             t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#                 document,'script','https://connect.facebook.net/en_US/fbevents.js');
#
#         fbq('init', '1582751422022883');
#         </script>
#         <noscript>
#          <img height="1" src="https://www.facebook.com/tr?id=1582751422022883&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#         </noscript>
#         <!-- End Facebook Pixel Code -->
#         <!-- Google Analytics -->
#         <script>
#          (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                 m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#         ga('create', 'UA-30875919-1', 'auto');
#         ga('send', 'pageview');
#         </script>
#         <!-- Google Analytics -->
#         <!-- Zarget code -->
#         <script src="//cdn.zarget.com/113982/209089.js">
#         </script>
#         <!-- Zarget code -->
#         <!-- Google Recaptcha -->
#         <script src="https://www.google.com/recaptcha/api.js">
#         </script>
#         <!-- Google Recaptcha -->
#         <style>
#         </style>
#         <script src="/88cb00e7070fce84c4e6298258d61bde/assets/js/result.pre.min.js">
#         </script>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="buy-service results-page">
#   <header class="navbar yamm navbar-default navbar-fixed-top" style="height: 0;min-height: 55px; position: fixed; margin-bottom: 0;">
#    <div class="container min-800" style="padding: 0 20px !important;">
#     <div class="navbar-header">
#      <a class="navbar-brand" href="http://www.buyrentkenya.com">
#       <img alt="Buy Rent Kenya Ltd" src="/88cb00e7070fce84c4e6298258d61bde/assets/images/logo/logo-big.png" style="margin-top: -8px;max-width: inherit;"/>
#      </a>
#     </div>
#     <div>
#      <!--  start login/register -->
#      <!-- end login/register -->
#      <ul class="userButtons">
#       <li class="userBtn">
#        <a class="buttonGrey" href="http://www.buyrentkenya.com/new-listing" id="new-listing" style="padding: 8px 27px 10px 27px !important;">
#         <i class="fa fa-fw fa-plus">
#         </i>
#         Add Your Property
#        </a>
#       </li>
#      </ul>
#      <ul class="nav navbar-nav" style="font-family: arial, verdana, helvetica;">
#       <li class="dropdown yamm-fw">
#        <a href="http://www.buyrentkenya.com">
#         Home
#        </a>
#       </li>
#       <li class="dropdown yamm-fw">
#        <a href="/new-project/results" style="color: #ad2122;font-weight: bold;font-family: arial, verdana, helvetica;font-size: 14px;-webkit-font-smoothing: antialiased;text-decoration: none;">
#         New Projects
#        </a>
#       </li>
#       <li class="dropdown yamm-fw">
#        <a href="http://www.buyrentkenya.com/blog">
#         Blog
#        </a>
#       </li>
#       <li class="dropdown yamm-fw">
#        <a href="http://www.buyrentkenya.com/contact">
#         Contact Us
#        </a>
#       </li>
#      </ul>
#     </div>
#     <!--/.navbar-collapse -->
#    </div>
#    <!-- end header container -->
#   </header>
#   <!-- End Header -->
#   <!-- Start Google remarketting tags -->
#   <script type="text/javascript">
#    var google_tag_params = {
#             listing_id: 'N/A',
#             listing_pagetype: 'buy results',
#             listing_totalvalue: '',
#             listing_location: 'Eldoret'
#         };
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
#         var google_conversion_id = 986750176;
#         var google_custom_params = window.google_tag_params;
#         var google_remarketing_only = true;
#         /* ]]> */
#   </script>
#   <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
#   </script>
#   <noscript>
#    <div style="display:inline;">
#     <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/986750176/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
#    </div>
#   </noscript>
#   <!-- End Google remarketting tags -->
#   <div id="exitpopup_bg" style="display: none !important;">
#   </div>
#   <div id="exitpopup" style="display: none !important;">
#    <img id="close" src="/assets/images/icon-close.png"/>
#    <span id="subscribe-title">
#     Did you find what you were looking for ?
#    </span>
#    <p>
#     We would like to let you know about properties we will find matching your specifications.
#    </p>
#    <form class="form" id="new-subscriber-form">
#     <input id="_token" name="_token" style="display: none" type="hidden" value="HMPgXUrrjGuDRNIk6Bg7GCe3Hq6iklZNVUuotW3q"/>
#     <input id="query_url" name="query_url" style="display: none" type="hidden" value="http://api.buyrentkenya.com/api/advert?transaction=buy&amp;sort=default&amp;filters[location_id][in]=434,435,436,2680,2668,2669,2670,2671,2672,2673,2674,2675,2676,2677,2678,2679,2680,2681,2682,2683,2684,2685,2686,2687,2688,2689,2690,2691,2692,2693,2694,2695,2696,2697,2698,2699,2700,2701,2702,2703,2705,2706,2707,2708,2709"/>
#     <input id="search" name="search" style="display: none" type="hidden" value="buy"/>
#     <input id="location" name="location" style="display: none" type="hidden" value="Eldoret"/>
#     <input id="popup_appeared" name="popup_appeared" style="display: none" type="hidden" value=""/>
#     <input id="subscriber_email" name="subscriber_email" placeholder="Enter your email address" type="email"/>
#     <br/>
#     <span class="btn btn-search primary subscription-btn" onmouseup="validateSubscriber();">
#      <i class="fa fa-envelope-o" style="color: #FFF !important;font-weight: bold;">
#      </i>
#      Sign up for alerts
#     </span>
#    </form>
#   </div>
#   <div class="body-wrapper" id="main-content">
#    <div class="content-wrapper">
#     <div class="buy-container-left-section" style="float: left; width: 70%; ">
#      <!--MAIN RESULTS PAGE CONTENT START-->
#      <div class="main-container-left-section">
#       <div id="brk-filters-container-parent">
#        <div class="brk-filters-container">
#         <div class="brk-filters-header">
#          <div class="brk-filters-tab brk-filters-tab-main brk-filters-tab-label-text separator" data-f-type="brk-filters-text-common">
#           <i class="fa fa-sliders">
#           </i>
#           <span class="brk-filters-label-text">
#            Filter
#           </span>
#          </div>
#          <div class="brk-filter-box">
#           <div class="brk-filter-budget-common brk-filters-header-budget brk-filters-tab separator" data-f-type="brk-filters-budget-common">
#            <span class="brk-filters-label-text">
#             Budget
#            </span>
#           </div>
#           <div class="brk-filter-bhk-common brk-filters-header-bhk brk-filters-tab separator">
#            <span class="brk-filters-label-text">
#             Bedroom
#            </span>
#           </div>
#           <div class="brk-filter-bhk-common brk-filters-header-bhk brk-filters-tab separator">
#            <span class="brk-filters-label-text">
#             Bathroom
#            </span>
#           </div>
#           <div class="brk-filter-bhk-common brk-filters-header-type brk-filters-tab separator filter-property brk-filters-header-type-buy">
#            <span class="brk-filters-label-text">
#             Type
#            </span>
#           </div>
#           <div class="brk-filter-bhk-common brk-filters-header-amenity brk-filters-tab separator brk-filters-header-amenity-buy">
#            <span class="brk-filters-label-text">
#             Amenities
#            </span>
#           </div>
#          </div>
#         </div>
#         <div class="filters-body">
#          <div class="filters-body-primary">
#           <div class="body-separator filter-budget filter-budget-common filter-columns filter-columns-first">
#            <div class="range-filter range-filter-view filter filter-container dropdown range-filter-inside">
#             <div class="dropdown-filter-wrapper">
#              <form action="http://www.buyrentkenya.com/buy/results" class="clearfix" id="all-filters">
#               <div class="range-header">
#                <input class="box lower-box-price" data-sample="lower" data-value="0" name="filters[asking_price][egt]" placeholder="Min" tabindex="0"/>
#                <input class="box upper-box-price" data-sample="upper" data-value="0" name="filters[asking_price][elt]" placeholder="Max" tabindex="0"/>
#                <div id="hidden-inputs-container" style="display:none">
#                </div>
#                <input name="location" type="hidden" value="Eldoret"/>
#               </div>
#               <div class="always-show no-border range-list-wrapper">
#                <ul class="lower-list range-list" style="text-transform: uppercase">
#                 <li class="lower-range-item" onmouseup="setClickedFilters()" value="0">
#                  0
#                 </li>
#                 <li class="lower-range-item" onmouseup="setClickedFilters()" value="1000000">
#                  1m
#                 </li>
#                 <li class="lower-range-item" onmouseup="setClickedFilters()" value="3000000">
#                  3m
#                 </li>
#                 <li class="lower-range-item" onmouseup="setClickedFilters()" value="5000000">
#                  5m
#                 </li>
#                 <li class="lower-range-item" onmouseup="setClickedFilters()" value="7000000">
#                  7m
#                 </li>
#                 <li class="lower-range-item" onmouseup="setClickedFilters()" value="12000000">
#                  12m
#                 </li>
#                 <li class="lower-range-item" onmouseup="setClickedFilters()" value="25000000">
#                  25m
#                 </li>
#                 <li class="lower-range-item" onmouseup="setClickedFilters()" value="50000000">
#                  50m
#                 </li>
#                 <li class="lower-range-item" onmouseup="setClickedFilters()" value="100000000">
#                  100m
#                 </li>
#                </ul>
#                <ul class="range-list upper-list" style="text-transform: uppercase">
#                 <li class="upper-range-item" onmouseup="setClickedFilters()" value="1000000">
#                  1m
#                 </li>
#                 <li class="upper-range-item" onmouseup="setClickedFilters()" value="3000000">
#                  3m
#                 </li>
#                 <li class="upper-range-item" onmouseup="setClickedFilters()" value="5000000">
#                  5m
#                 </li>
#                 <li class="upper-range-item" onmouseup="setClickedFilters()" value="7000000">
#                  7m
#                 </li>
#                 <li class="upper-range-item" onmouseup="setClickedFilters()" value="12000000">
#                  12m
#                 </li>
#                 <li class="upper-range-item" onmouseup="setClickedFilters()" value="25000000">
#                  25m
#                 </li>
#                 <li class="upper-range-item" onmouseup="setClickedFilters()" value="50000000">
#                  50m
#                 </li>
#                 <li class="upper-range-item" onmouseup="setClickedFilters()" value="100000000">
#                  100m
#                 </li>
#                 <li class="upper-range-item" onmouseup="setClickedFilters()" value="">
#                  100m +
#                 </li>
#                </ul>
#               </div>
#              </form>
#             </div>
#            </div>
#           </div>
#           <div class="body-separator filter-bhk filter-bhk-common filter-columns">
#            <div class="btn-group btn-vertical">
#             <span class="label">
#              BR+
#             </span>
#             <div class="row filter-row">
#              <div class="amenityCheck col-lg-6 col-md-12">
#               <input class="bedroom-check" id="1-bedroom" type="checkbox" value="1"/>
#               <label for="1">
#                1 BR
#               </label>
#              </div>
#              <div style="clear:both;">
#              </div>
#              <div class="amenityCheck col-lg-6 col-md-12">
#               <input class="bedroom-check" id="2-bedroom" type="checkbox" value="2"/>
#               <label for="1">
#                2 BR
#               </label>
#              </div>
#              <div style="clear:both;">
#              </div>
#              <div class="amenityCheck col-lg-6 col-md-12">
#               <input class="bedroom-check" id="3-bedroom" type="checkbox" value="3"/>
#               <label for="1">
#                3 BR
#               </label>
#              </div>
#              <div style="clear:both;">
#              </div>
#              <div class="amenityCheck col-lg-6 col-md-12">
#               <input class="bedroom-check" id="4-bedroom" type="checkbox" value="4"/>
#               <label for="1">
#                4 BR
#               </label>
#              </div>
#              <div style="clear:both;">
#              </div>
#              <div class="amenityCheck col-lg-6 col-md-12">
#               <input class="bedroom-check" id="5-bedroom" type="checkbox" value="5"/>
#               <label for="1">
#                5 BR
#               </label>
#              </div>
#              <div style="clear:both;">
#              </div>
#              <div class="amenityCheck col-lg-6 col-md-12">
#               <input class="bedroom-check" id="5+-bedroom" type="checkbox" value="5+"/>
#               <label for="1">
#                5 BR +
#               </label>
#              </div>
#              <div style="clear:both;">
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="body-separator filter-bhk filter-bhk-common filter-columns">
#            <div class="btn-group btn-vertical">
#             <span class="label">
#              BT+
#             </span>
#             <div class="row filter-row">
#              <div class="amenityCheck col-lg-6 col-md-12">
#               <input class="bathroom-check" id="1-bathroom" type="checkbox" value="1"/>
#               <label for="1">
#                1
#               </label>
#              </div>
#              <div style="clear:both;">
#              </div>
#              <div class="amenityCheck col-lg-6 col-md-12">
#               <input class="bathroom-check" id="2-bathroom" type="checkbox" value="2"/>
#               <label for="1">
#                2
#               </label>
#              </div>
#              <div style="clear:both;">
#              </div>
#              <div class="amenityCheck col-lg-6 col-md-12">
#               <input class="bathroom-check" id="3-bathroom" type="checkbox" value="3"/>
#               <label for="1">
#                3
#               </label>
#              </div>
#              <div style="clear:both;">
#              </div>
#              <div class="amenityCheck col-lg-6 col-md-12">
#               <input class="bathroom-check" id="4-bathroom" type="checkbox" value="4"/>
#               <label for="1">
#                4
#               </label>
#              </div>
#              <div style="clear:both;">
#              </div>
#              <div class="amenityCheck col-lg-6 col-md-12">
#               <input class="bathroom-check" id="5-bathroom" type="checkbox" value="5"/>
#               <label for="1">
#                5
#               </label>
#              </div>
#              <div style="clear:both;">
#              </div>
#              <div class="amenityCheck col-lg-6 col-md-12">
#               <input class="bathroom-check" id="5+-bathroom" type="checkbox" value="5+"/>
#               <label for="1">
#                5 +
#               </label>
#              </div>
#              <div style="clear:both;">
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="body-separator filter-columns filter-columns-first filter-property filter-property-buy">
#            <div class="filter filter-container filter-multiple property_types filter-count-7">
#             <div class="btn-group">
#              <span class="label">
#               Property Type
#              </span>
#              <div class="row filter-row">
#               <div class="amenityCheck col-lg-6 col-md-12">
#                <input class="type-check" id="type-apartment" type="checkbox" value="apartment"/>
#                <label for="1">
#                 Flats / Apartments
#                </label>
#               </div>
#               <div style="clear:both;">
#               </div>
#               <div class="amenityCheck col-lg-6 col-md-12">
#                <input class="type-check" id="type-house" type="checkbox" value="house"/>
#                <label for="1">
#                 House / Villa
#                </label>
#               </div>
#               <div style="clear:both;">
#               </div>
#               <div class="amenityCheck col-lg-6 col-md-12">
#                <input class="type-check" id="type-townhouse" type="checkbox" value="townhouse"/>
#                <label for="1">
#                 Townhouse(Gated comm)
#                </label>
#               </div>
#               <div style="clear:both;">
#               </div>
#               <div class="amenityCheck col-lg-6 col-md-12">
#                <input class="type-check" id="type-dsq" type="checkbox" value="dsq"/>
#                <label for="1">
#                 Bedsitter / Room
#                </label>
#               </div>
#               <div style="clear:both;">
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="body-separator filter-amenities filter-columns">
#            <div class="filter filter-container">
#             <div class="btn-group">
#              <span class="label">
#               Amenities
#              </span>
#              <div class="row filter-row">
#               <div class="amenityCheck col-lg-6 col-md-12">
#                <input class="amenity-check" id="feature-features_num_parkings" type="checkbox" value="features_num_parkings"/>
#                <label for="1">
#                 Parking
#                </label>
#               </div>
#               <div style="clear:both;">
#               </div>
#               <div class="amenityCheck col-lg-6 col-md-12">
#                <input class="amenity-check" id="feature-features_has_gym" type="checkbox" value="features_has_gym"/>
#                <label for="1">
#                 Gym
#                </label>
#               </div>
#               <div style="clear:both;">
#               </div>
#               <div class="amenityCheck col-lg-6 col-md-12">
#                <input class="amenity-check" id="feature-features_has_staff_quarters" type="checkbox" value="features_has_staff_quarters"/>
#                <label for="1">
#                 Staff Quarter
#                </label>
#               </div>
#               <div style="clear:both;">
#               </div>
#               <div class="amenityCheck col-lg-6 col-md-12">
#                <input class="amenity-check" id="feature-features_has_swiming_pool" type="checkbox" value="features_has_swiming_pool"/>
#                <label for="1">
#                 Swimming Pool
#                </label>
#               </div>
#               <div style="clear:both;">
#               </div>
#               <div class="amenityCheck col-lg-6 col-md-12">
#                <input class="amenity-check" id="feature-features_has_kitchen" type="checkbox" value="features_has_kitchen"/>
#                <label for="1">
#                 Kitchen
#                </label>
#               </div>
#               <div style="clear:both;">
#               </div>
#               <div class="amenityCheck col-lg-6 col-md-12">
#                <input class="amenity-check" id="feature-features_is_furnished" type="checkbox" value="features_is_furnished"/>
#                <label for="1">
#                 Furnished
#                </label>
#               </div>
#               <div style="clear:both;">
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <hr style="margin-bottom: 0px;margin-top: 2px;"/>
#           <div class="row filter-row" style="background: #f4f4f4;">
#            <div class="btn get-alerts secondary" id="refresh-results" onmouseup="submitFilters()">
#             <i class="fa fa-rotate-right">
#             </i>
#             <span class="text" type="submit">
#              <b>
#               <span class="arial-bold">
#                Apply filters
#               </span>
#              </b>
#             </span>
#            </div>
#            <div class="btn get-alerts secondary" id="remove-filters" onmouseup="clearFilters()">
#             <i class="fa fa-remove">
#             </i>
#             <span class="text" type="submit">
#              <b>
#               <span class="arial-bold">
#                Remove filters
#               </span>
#              </b>
#             </span>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="pagination pagination-brk-filter" style="opacity: 0; background: none !important; margin-bottom: 0 !important;">
#       </div>
#       <div class="results-container" data-backend-printed="true">
#        <!--RESULT COUNT START-->
#        <div id="brk-filter-results-container">
#         <div class="results-info-container">
#          <span class="breadcrumb-container">
#           <div class="bread-crumbs">
#            <li>
#             <a href="/">
#              <span itemprop="name">
#               Home
#              </span>
#             </a>
#            </li>
#            <span>
#             /
#            </span>
#            <li>
#             <a href="/buy/results">
#              <span itemprop="name">
#               Buy
#              </span>
#             </a>
#            </li>
#            <span>
#             /
#            </span>
#            <li>
#             <a href="/property-for-sale-in-uasin-gishu-143.html">
#              <span itemprop="name">
#               Uasin Gishu
#              </span>
#             </a>
#            </li>
#            <span>
#             /
#            </span>
#            <li>
#             <a href="/property-for-sale-in-eldoret-south-436.html">
#              <span itemprop="name">
#               Eldoret South
#              </span>
#             </a>
#            </li>
#            <span>
#             /
#            </span>
#            <li>
#             <span itemprop="name">
#              Eldoret
#             </span>
#            </li>
#           </div>
#           <div id="change-transaction-div">
#            <select id="change-transaction" style="font-size: 13px; font-weight: 600;">
#             <option selected="" value="buy">
#              Buy
#             </option>
#             <option value="rent">
#              Rent
#             </option>
#             <option value="land">
#              Land
#             </option>
#             <option value="commercial">
#              Commercial
#             </option>
#             <option value="new-project">
#              New Projects
#             </option>
#            </select>
#            <input data-toggle="tooltip" id="change-location" name="location" placeholder="change location" style="width: 140px;margin-bottom: 0;height: 30px;color: #6F7072;font-family: Helvetica Neue,Helvetica,Arial,Helmet,Freesans,sans-serif;font-size: 14px;" title="Please enter location"/>
#            <div class="btn get-alerts secondary" id="change-location-btn" style="line-height: 29px;">
#             <span class="text arial-bold">
#              Search
#             </span>
#            </div>
#           </div>
#          </span>
#          <h1 class="results-title" style="color: #B5121B !important;font-family: Raleway,sans-serif !important;">
#           Properties for sale in Eldoret
#          </h1>
#         </div>
#        </div>
#        <!--RESULT COUNT END-->
#        <!--SORTING BAR START-->
#        <style>
#         a{ outline: none !important; }
#        </style>
#        <div class="sort-container-parent">
#         <!-- Clean URL -->
#         <!-- Set sort parameters -->
#         <div class="sort-container">
#          <div class="sort-by text">
#           Sort by
#          </div>
#          <div class="pipe">
#          </div>
#          <div class="text">
#           Price:
#          </div>
#          <a href="http://www.buyrentkenya.com/buy/results?location=Eldoret&amp;sort=asking_price&amp;" rel="nofollow">
#           <div class="clickable group" data-id="price">
#            Low
#           </div>
#          </a>
#          <a href="http://www.buyrentkenya.com/buy/results?location=Eldoret&amp;sort=-asking_price&amp;" rel="nofollow">
#           <div class="clickable group" data-id="price">
#            High
#           </div>
#          </a>
#          <div class="pipe">
#          </div>
#          <div class="text">
#           Bedrooms:
#          </div>
#          <a href="http://www.buyrentkenya.com/buy/results?location=Eldoret&amp;sort=features_num_bedrooms&amp;" rel="nofollow">
#           <div class="clickable group" data-id="price">
#            Ascending
#           </div>
#          </a>
#          <a href="http://www.buyrentkenya.com/buy/results?location=Eldoret&amp;sort=-features_num_bedrooms&amp;" rel="nofollow">
#           <div class="clickable group" data-id="price">
#            Descending
#           </div>
#          </a>
#          <div class="pipe">
#          </div>
#          <a href="http://www.buyrentkenya.com/buy/results?location=Eldoret&amp;sort=verified&amp;" rel="nofollow">
#           <div class="clickable group" data-id="verified">
#            Verified Properties
#           </div>
#          </a>
#          <div class="pipe">
#          </div>
#          <a href="http://www.buyrentkenya.com/buy/results?location=Eldoret&amp;sort=-created_at&amp;" rel="nofollow">
#           <div class="clickable" data-id="date_added">
#            Most Recent
#           </div>
#          </a>
#         </div>
#        </div>
#        <!--SORTING BAR END-->
#        <!--RESULT AREA START-->
#        <div style="display: none;">
#         <input id="detail_added_on_27790" type="hidden" value="ADDED ON Tuesday 26th, January 2016"/>
#         <input id="detail_title_27790" type="hidden" value="6 Bedrooms Townhouse For Sale In Langas"/>
#         <input id="detail_description_27790" type="hidden" value="Location: Eldoret- Langas
#
# - 6 Bedroom + DSQ
# - 6 Bedroom (all Ensuite) + Visitors Toilet + DSQ
#
# PRICE: Ksh 15 Million
#
# COMMON AMENITIES
#
# Security
# Green Spaces
# A planned mini Township
# Lifestyle living
# Dream homes at value for money
# Ample Parking
# A Club House within your society with all amenities
# Solar street lights
# Full perimeter security system with electrical fence
#
# TOWN HOUSE FEATURES
#
# 6 Bedrooms, all en-suite
# Master bedroom with walking wardrobe
# Large living room finish with vitrified tiles
# UPVC white window with Tinted glass
# Superior quality paints on internal walls
# Standard electrical switches
# Instant water heater
# Flush door with Veneer Finish
# Smart steel door at main entrance
# High quality tiles, sanitary ware &amp; sanitary fittings
# Anti termite treatment for foundation
# Internal wall finished with gypsum plaster
# Tile dado above the platform
# Tiles finished internal staircase
# Interlock concrete paving block for parking area                                                                                                                                                            "/>
#         <input id="detail_agency_name_27790" type="hidden" value="Kings Developers"/>
#         <input id="detail_images27790" type="hidden" value="http://api.buyrentkenya.com/api/storage/images/2016/1/26/IOBpzgZxa6xYDGb4xuyypboCJNgPKbCMf85tvfd1.jpg,http://api.buyrentkenya.com/api/storage/images/2016/1/26/6tf4EGRNICowy27i7Y6c2mA7KTvF4vKUjkdcDYgZ.jpg,http://api.buyrentkenya.com/api/storage/images/2016/1/26/nBwhgJFmVODl94Gdspi6psZ5doVVI557VmsDWWkl.jpg,http://api.buyrentkenya.com/api/storage/images/2016/1/26/qjCBRa63ikOBiVOS9NdE4ooIyq27lFmhyMC5apYd.jpg,http://api.buyrentkenya.com/api/storage/images/2016/1/26/RKIDn4pJviF7reFqwTUDNIeobpeat2dNdI28Nz1s.jpg,http://api.buyrentkenya.com/api/storage/images/2016/1/26/Wl8IonUMJeNS6ts6Z51UIgNZeBuDnaOpBtKYGo7X.jpg,http://api.buyrentkenya.com/api/storage/images/2016/1/26/lL0PoFxM175n9s38WAOSXJTClixWZuiKCkNXN4M4.jpg,"/>
#         <input id="detail_reference_number27790" type="hidden" value="S35900"/>
#         <input id="detail_address_location_longitude_27790" type="hidden" value="37.91"/>
#         <input id="detail_address_location_latitude_27790" type="hidden" value="-0.02"/>
#         <input id="detail_address_area_name_27790" type="hidden" value="Uasin Gishu"/>
#         <input id="detail_address_location_name_27790" type="hidden" value="Eldoret South"/>
#         <input id="detail_address_suburb_name_27790" type="hidden" value="Langas"/>
#         <input id="detail_address_street_name_27790" type="hidden" value="6 BD Maisonette Eldoret"/>
#         <input id="detail_images_27790" type="hidden" value="http://api.buyrentkenya.com/api/storage/images/2016/1/26/IOBpzgZxa6xYDGb4xuyypboCJNgPKbCMf85tvfd1.jpg,http://api.buyrentkenya.com/api/storage/images/2016/1/26/6tf4EGRNICowy27i7Y6c2mA7KTvF4vKUjkdcDYgZ.jpg,http://api.buyrentkenya.com/api/storage/images/2016/1/26/nBwhgJFmVODl94Gdspi6psZ5doVVI557VmsDWWkl.jpg,http://api.buyrentkenya.com/api/storage/images/2016/1/26/qjCBRa63ikOBiVOS9NdE4ooIyq27lFmhyMC5apYd.jpg,http://api.buyrentkenya.com/api/storage/images/2016/1/26/RKIDn4pJviF7reFqwTUDNIeobpeat2dNdI28Nz1s.jpg,http://api.buyrentkenya.com/api/storage/images/2016/1/26/Wl8IonUMJeNS6ts6Z51UIgNZeBuDnaOpBtKYGo7X.jpg,http://api.buyrentkenya.com/api/storage/images/2016/1/26/lL0PoFxM175n9s38WAOSXJTClixWZuiKCkNXN4M4.jpg,"/>
#         <input id="detail_features_27790" type="hidden" value='{"features_has_electric_fencing":{"field":"features_has_electric_fencing","label":"Electric Fence","is_important":0,"is_interior_feature":0,"type":"boolean","base_64_icon":0},"features_has_staff_quarters":{"field":"features_has_staff_quarters","label":"Staff Quarter","is_important":0,"is_interior_feature":1,"type":"boolean","base_64_icon":0},"features_has_walk_in_closet":{"field":"features_has_walk_in_closet","label":"Walk In Closet","is_important":0,"is_interior_feature":1,"type":"boolean","base_64_icon":0},"features_has_swiming_pool":{"field":"features_has_swiming_pool","label":"Swimming Pool","is_important":1,"is_interior_feature":0,"type":"boolean","base_64_icon":0},"features_has_gym":{"field":"features_has_gym","label":"Gym","is_important":1,"is_interior_feature":0,"type":"boolean","base_64_icon":0},"features_num_bedrooms":{"field":"features_num_bedrooms","label":"Bedroom","is_important":1,"is_interior_feature":1,"type":"int","base_64_icon":0},"features_num_bathrooms":{"field":"features_num_bathrooms","label":"Bathroom","is_important":1,"is_interior_feature":1,"type":"int","base_64_icon":0},"features_has_club_house":{"field":"features_has_club_house","label":"Club House","is_important":0,"is_interior_feature":0,"type":"boolean","base_64_icon":0},"features_has_guest_toilet":{"field":"features_has_guest_toilet","label":"Guest Toilet","is_important":0,"is_interior_feature":1,"type":"boolean","base_64_icon":0}}'/>
#         <input id="detail_user_27790" type="hidden" value='{"id":"1488","gender":"man","firstname":"Kings","lastname":"Developers","phone":"7706978002","address":null,"address_2":null,"postal_code":null,"city":null,"country_id":"115","created_at":"2015-09-08 18:56:32","updated_at":"2017-05-02 11:27:33","deleted_at":null,"parent_id":"733","name":null,"logo":null,"description":"","fax":null,"website":"","dob":"0000-00-00","vat_number":null,"facebook":null,"twitter":null,"position":"Manager","country":{"id":"115","code":"KE","number":"","iso":"KEN","phone":"254","en":"Kenya","fr":"Kenya"},"parent":{"id":"733","gender":"man","firstname":null,"lastname":"","phone":"254729459277","address":"Kings Developers Ltd.Saj Ceramics Complex, 2nd Floor,Opp. Cabanas Grounds,Embakasi, Mombasa Road,P.O. Box No. 18215-00500,Nairobi, Kenya.","address_2":null,"postal_code":null,"city":null,"country_id":"115","created_at":"2015-09-08 18:51:03","updated_at":"2016-05-10 09:10:24","deleted_at":null,"parent_id":"345","name":"Kings Developers","logo":null,"description":"","fax":"","website":"http:\/\/www.kingsdevelopers.com\/","dob":"0000-00-00","vat_number":null,"facebook":null,"twitter":null,"position":null,"email":"info@kingsdevelopers.com","status":"1","type":"office","mobilephone":"0734195020","active_at":null,"archived_at":null,"auto_expiry":null,"auto_publish":"0","lead_quota":null,"0":734195020,"parent":null,"is_pro":true,"stats":{"listings":{"own":{"total":0,"online":0,"archived":0},"hierarchy":{"total":0,"online":0,"archived":0}},"users":{"active":2,"deleted":0},"lead":{"quota":1501,"email":1153,"phone":96,"total":1249,"remaining":252},"moderation":{"approvals":0,"rejections":0,"validations":0}}},"email":"vinayak@royalgroupkenya.com","status":"1","type":"individual","mobilephone":"254706978002","active_at":"2017-02-27 06:28:49","archived_at":null,"auto_expiry":null,"auto_publish":"1","lead_quota":null,"0":254706978002,"agency_id":"345","is_pro":true,"stats":{"listings":{"own":{"total":22,"online":18,"archived":0},"hierarchy":{"total":22,"online":18,"archived":0}},"users":{"active":1,"deleted":0},"lead":{"quota":1501,"email":1153,"phone":96,"total":1249,"remaining":252},"moderation":{"approvals":45,"rejections":0,"validations":45}}}'/>
#         <input id="detail_agency_27790" type="hidden" value='{"id":"345","gender":"man","firstname":null,"lastname":"","phone":"254202044619","address":"","address_2":null,"postal_code":"","city":"","country_id":"0","created_at":"2015-09-08 18:49:52","updated_at":"2017-10-05 13:53:32","deleted_at":null,"parent_id":"0","name":"Kings Developers","logo":"http:\/\/api.buyrentkenya.com\/api\/storage\/images\/2015\/9\/8\/Yzo3EJ1UtvvmH1ggKKSvmcOGDPNtcWy56zww4n8R.jpg","description":null,"fax":null,"website":null,"dob":"0000-00-00","vat_number":"","facebook":null,"twitter":null,"position":null,"country":null,"parent":null,"email":"vinayak@royalgroupkenya.com","status":"1","type":"agency","mobilephone":"254706978002","active_at":"2017-10-05 10:53:32","archived_at":null,"auto_expiry":null,"auto_publish":"0","lead_quota":"1501","0":254706978002,"is_pro":true,"stats":{"listings":{"own":{"total":0,"online":0,"archived":0},"hierarchy":{"total":0,"online":0,"archived":0}},"users":{"active":3,"deleted":0},"lead":{"quota":1501,"email":1153,"phone":96,"total":1249,"remaining":252},"moderation":{"approvals":0,"rejections":0,"validations":0}}}'/>
#         <input id="detail_contact_logo_27790" type="hidden" value="http://api.buyrentkenya.com/api/storage/images/2015/9/8/Yzo3EJ1UtvvmH1ggKKSvmcOGDPNtcWy56zww4n8R.jpg"/>
#         <input id="detail_hide_price_27790" type="hidden" value="0"/>
#         <input id="detail_price_27790" type="hidden" value="KES 17,000,000"/>
#         <input id="detail_overview_27790" type="hidden" value='{"purpose":"For Sale", "ref":"S35900","type":"Townhouse", "county":"Uasin Gishu", "location":"Eldoret South", "area":"Langas", "bedrooms":6, "bathrooms": 6,"asking":"KES 17,000,000", "advertiser_type":"Agency", "land_area_size":"0.00", "floor_area_size":"0.00", "days_online":617 }'/>
#         <input id="detail_contact_submit_url_27790" type="hidden" value="http://www.buyrentkenya.com/details/27790/contact"/>
#         <input id="detail_default_photo_url_27790" type="hidden" value="1"/>
#         <input id="detail_listing_url_27790" onclick="updateDetailsPage(27790)" type="hidden" value="/uasin-gishu/eldoret-south/buy/6-bedrooms-townhouse-for-sale-in-langas-27790.html"/>
#         <input id="detail_transaction_27790" type="hidden" value="buy"/>
#         <input id="detail_features_is_rental_27790" type="hidden" value="0"/>
#         <input id="detail_features_is_featured_27790" type="hidden" value="0"/>
#         <input id="detail_features_is_verified_27790" type="hidden" value="0"/>
#         <input id="detail_features_is_premium_27790" type="hidden" value="0"/>
#        </div>
#        <div class="result-item list-card-item">
#         <input class="result-item-advert-id" type="hidden" value="27790">
#          <input class="result-item-price" type="hidden" value="17,000,000">
#           <input class="result-item-user-id" type="hidden" value="1488">
#            <input class="result-item-type" type="hidden" value="TOWNHOUSE">
#             <input class="result-item-transaction" type="hidden" value="buy">
#              <input class="result-item-image" type="hidden" value="http://api.buyrentkenya.com/api/storage/images/2016/1/26/IOBpzgZxa6xYDGb4xuyypboCJNgPKbCMf85tvfd1.jpg">
#               <input class="result-item-reference-number" type="hidden" value="S35900">
#                <input class="result-item-title" type="hidden" value="6 Bedrooms Townhouse For Sale In Langas">
#                 <input class="result-item-link" type="hidden" value="/uasin-gishu/eldoret-south/buy/6-bedrooms-townhouse-for-sale-in-langas-27790.html">
#                  <div class="list-card list-resale">
#                   <span id="thumbnail-preview">
#                    <a class="cd-nav-trigger propertyImgLink" href="/uasin-gishu/eldoret-south/buy/6-bedrooms-townhouse-for-sale-in-langas-27790.html" onclick="updateDetailsPage(27790)">
#                     <img alt="6 Bedrooms Townhouse For Sale In Langas" class="list-thumbnail" onerror="this.src='../../assets/images/placeholders/property.jpg'" src="http://api.buyrentkenya.com/api/storage/images/2016/1/26/IOBpzgZxa6xYDGb4xuyypboCJNgPKbCMf85tvfd1.jpg">
#                     </img>
#                    </a>
#                    <ul class="home-in home-in-27790">
#                     <li>
#                      <span>
#                       <i class="fa fa-bed">
#                       </i>
#                       6 Bedrooms
#                      </span>
#                     </li>
#                     <li>
#                      <span>
#                       <i class="fa fa-tty">
#                       </i>
#                       6 Bathrooms
#                      </span>
#                     </li>
#                    </ul>
#                   </span>
#                   <div class="list-details" style="cursor: default !important;">
#                    <div class="list-name">
#                     <a class="cd-nav-trigger" href="/uasin-gishu/eldoret-south/buy/6-bedrooms-townhouse-for-sale-in-langas-27790.html" onclick="updateDetailsPage(27790)">
#                      <b>
#                       6 Bedrooms Townhouse For Sale In Langas
#                      </b>
#                     </a>
#                    </div>
#                    <div class="list-landmark">
#                     <a class="list-landmark" href="http://www.buyrentkenya.com/townhouses-for-sale-in-uasin-gishu-143.html">
#                      Uasin Gishu
#                     </a>
#                     ≫
#                     <a class="list-landmark" href="http://www.buyrentkenya.com/townhouses-for-sale-in-eldoret-south-436.html">
#                      Eldoret South
#                     </a>
#                     ≫
#                     <a class="list-landmark" href="http://www.buyrentkenya.com/townhouses-for-sale-in-langas-2699.html">
#                      Langas
#                     </a>
#                    </div>
#                    <span class="home-in no-bg">
#                     <p class="no-pad">
#                      <strong>
#                       <b>
#                        KES 17,000,000
#                       </b>
#                      </strong>
#                     </p>
#                     <div class="list-right">
#                      <a class="btn arial-bold green-switch list-callback primary initialism agent-contacts-result_open btn btn-success" href="#agent-contacts-result" onclick="updateAgentPopup(27790)">
#                       Contact Agent
#                      </a>
#                      <div class="list-contacted">
#                      </div>
#                     </div>
#                    </span>
#                    <p style="height: 135px;">
#                     Location: eldoret- langas
#
# - 6 bedroom + dsq
# - 6 bedroom (all ensuite) + visitors toilet + dsq
#
# price: ksh 15 million
#
# common amenities
#
# security
# green spaces
# a planned mini township
# lifestyle living
# dream homes at value for money
# ample parking
# a club house within your society with a...
#                    </p>
#                    <ul class="propertyDetails-in">
#                     <li style="width: 20% !important;">
#                      <a class="cd-nav-trigger propertyImgLink" href="/uasin-gishu/eldoret-south/buy/6-bedrooms-townhouse-for-sale-in-langas-27790.html" onclick="updateDetailsPage(27790)">
#                       <span>
#                        <i class="fa fa-file-text">
#                        </i>
#                        <span class="arial-bold">
#                         View Details
#                        </span>
#                       </span>
#                      </a>
#                     </li>
#                     <li>
#                      <a class="agent-contacts-result_open propertyImgLink" href="#agent-contacts-result" onclick="updateAgentPopup(27790)">
#                       <span>
#                        <i class="fa fa-phone-square">
#                        </i>
#                        <span class="arial-bold" id="show-phone-27790">
#                         Please Call Me
#                        </span>
#                       </span>
#                      </a>
#                     </li>
#                     <li class="enquire visible-lg">
#                      <label class="enquiry-checkbox arial-bold" title="Select &amp; Enquire">
#                       <input data-id="27790" name="select_enquire" ref_number="S35900" style="margin-left: 5px;" type="checkbox"/>
#                       <small>
#                        Select &amp; Enquire
#                       </small>
#                      </label>
#                     </li>
#                    </ul>
#                   </div>
#                  </div>
#                 </input>
#                </input>
#               </input>
#              </input>
#             </input>
#            </input>
#           </input>
#          </input>
#         </input>
#        </div>
#        <div style="display: none;">
# ...
#                                  </option>
#                                  <option value="967">
#                                   YEM 967
#                                  </option>
#                                  <option value="260">
#                                   ZMB 260
#                                  </option>
#                                  <option value="263">
#                                   ZWE 263
#                                  </option>
#                                  <option value="358">
#                                   ALA 358
#                                  </option>
#                                 </select>
#                                </span>
#                                <input class="form-control txt-phone" name="phone" placeholder="Phone 0722 302..." type="text" value="">
#                                </input>
#                               </div>
#                               <p align="left" style="font-size: 14px;text-align: center;">
#                                Please note that your affordabilty for a mortgage is determined by a Debt Service Ratio (customer to qualify if less than 55%)
#                               </p>
#                               <input class="txt-phone" name="gross" placeholder="Gross income *" type="number">
#                                <input class="txt-phone" name="deductions" placeholder="Monthly deductions *" type="number">
#                                 <span id="min-deposit-error-message" style="display: none;text-align: center;">
#                                  <strong style="color: #CB0202">
#                                  </strong>
#                                 </span>
#                                 <input class="txt-phone" name="deposit" placeholder="Deposit Amount. Minimum 20%" type="number">
#                                  <input class="txt-phone" name="time" placeholder="Convenient time to be contacted" type="text">
#                                   <span class="btn-contact-container">
#                                    <button class="btn-contact" id="request-finance-submit-btn">
#                                     Send Request
#                                    </button>
#                                    <img alt="Loading..." height="55" id="contact-loading" src="images/loading.gif" width="54"/>
#                                   </span>
#                                   <div class="contact-error-field">
#                                   </div>
#                                  </input>
#                                 </input>
#                                </input>
#                               </input>
#                              </input>
#                             </input>
#                            </input>
#                           </input>
#                          </input>
#                         </input>
#                        </input>
#                       </input>
#                      </div>
#                      <div class="contact-message">
#                      </div>
#                     </input>
#                    </form>
#                   </div>
#                   <!-- Contact Financer form end-->
#                  </div>
#                 </div>
#                 <!-- Right column content ends -->
#                </div>
#               </div>
#              </div>
#              <!-- End Get Financing -->
#             </div>
#            </div>
#           </div>
#          </div>
#          <!-- END DETAIL-->
#         </div>
#        </div>
#       </div>
#       <div class="row-fluid">
#        <div class="col-md-12">
#         <div class="col-md-6">
#         </div>
#         <div class="col-md-6">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!--EndContent-->
#    </div>
#    <!-- End Wrapper-->
#   </nav>
#  </body>
# </html>
# <div class="cd-overlay">
#  <!-- shadow layer visible when navigation is visible -->
# </div>
# <!--QUICK VIEW SLIDE PANEL CONTAINER END-->
# <!-- start services section -->
# <section class="services" id="services-bottom-container">
#  <div class="container">
#   <span>
#    We make it
#    <span id="colored" style="font-family: 'proxima_novabold'; color: #ad2122; text-transform: uppercase;">
#     easy
#    </span>
#    . Here’s how.
#   </span>
#   <br>
#    <br>
#     <div class="row">
#      <div class="col-lg-4 col-md-4 col-sm-4">
#       <span class="principles" style="color: #ad2122;font-family: 'proxima_novabold' , Helvetica, Arial;font-size: 16px;">
#        INSPIRATION
#       </span>
#       <p>
#        <strong>
#         Be moved.
#        </strong>
#        You should be inspired when looking for your next home, it’s more than just an investment it’s a lifestyle choice. Great imagery, convenient features and beautiful properties all add up to make your house hunting an enjoyable experience.
#       </p>
#      </div>
#      <div class="col-lg-4 col-md-4 col-sm-4">
#       <span class="principles" style="color: #ad2122;font-family: 'proxima_novabold' , Helvetica, Arial;font-size: 16px;">
#        PERSONALITY
#       </span>
#       <p>
#        <strong>
#         People buy and sell property.
#        </strong>
#        We introduce you to the people behind the properties you love. Professional agents, private individuals or even our friendly team, we are working to put a face to every name.
#       </p>
#      </div>
#      <div class="col-lg-4 col-md-4 col-sm-4">
#       <span class="principles" style="color: #ad2122;font-family: 'proxima_novabold' , Helvetica, Arial;font-size: 16px;">
#        REALITY
#       </span>
#       <p>
#        <strong>
#         Property adverts so real you could move in.
#        </strong>
#        Virtual tours, videos, street maps, great descriptions and an industry first ‘Listing Score’ all help you pick the perfect place. We want you to fall in with.
#       </p>
#      </div>
#     </div>
#    </br>
#   </br>
#  </div>
# </section>
# <!-- end services section -->
# <!-- start regional content section -->
# <!-- end regional content section -->
# <div id="sticky-social-media-share" style="margin-bottom: 80px; display: none">
#  <a class="col-lg-3 col-md-3 col-sm-3 col-xs-3 ssk ssk-text ssk-facebook" href="https://www.facebook.com/buyrentkenya" style="margin-right: 0;padding-top: 28px;" target="_blank">
#   Join us on Facebook
#  </a>
#  <a class="col-lg-3 col-md-3 col-sm-3 col-xs-3 ssk ssk-text ssk-twitter" href="https://twitter.com/buyrentkenya" style="margin-right: 0;padding-top: 28px;" target="_blank">
#   Follow us on Twitter
#  </a>
#  <a class="col-lg-3 col-md-3 col-sm-3 col-xs-3 ssk ssk-text ssk-google-plus" href="https://plus.google.com/+BuyrentkenyaNairobi/posts" style="margin-right: 0;padding-top: 28px;" target="_blank">
#   Add to our Circle
#  </a>
#  <a class="col-lg-3 col-md-3 col-sm-3 col-xs-3 ssk ssk-text ssk-linkedin" href="https://www.linkedin.com/company/buyrentkenya-com" style="margin-right: 0;padding-top: 28px;" target="_blank">
#   Connect to our Network
#  </a>
# </div>
# <div id="seo-links-container">
#  <footer id="footer">
#   <div class="container">
#    <div class="seo-links">
#     <!-- Static SEO content -->
#     <div class="row">
#      <div class="col-lg-3 col-md-3 col-sm-6">
#       <span class="seo-link-header">
#        Popular buy searches
#       </span>
#       <ul>
#        <li class="menu-item">
#         <a href="/houses-for-sale-in-kenya-1.html">
#          Buy a house in Kenya
#         </a>
#        </li>
#        <li class="menu-item">
#         <a href="/apartments-for-sale-in-kenya-1.html">
#          Buy an apartment in Kenya
#         </a>
#        </li>
#        <li class="menu-item">
#         <a href="/land-for-sale-in-kenya-1.html">
#          Buy land in Kenya
#         </a>
#        </li>
#        <li class="menu-item">
#         <a href="/commercial-office-space-for-sale-in-kenya-1.html">
#          Buy commercial property in Kenya
#         </a>
#        </li>
#        <li class="menu-item">
#         <a href="/invest-real-estate-project-in-kenya.html">
#          Buy new projects in Kenya
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="col-lg-3 col-md-3 col-sm-6">
#       <span class="seo-link-header">
#        Popular rent searches
#       </span>
#       <ul>
#        <li class="menu-item">
#         <a href="/houses-for-rent-in-kenya-1.html">
#          Rent a house in Kenya
#         </a>
#        </li>
#        <li class="menu-item">
#         <a href="/apartments-for-rent-in-kenya-1.html">
#          Rent an apartment in Kenya
#         </a>
#        </li>
#        <li class="menu-item">
#         <a href="/land-for-rent-in-kenya-1.html">
#          Rent land in Kenya
#         </a>
#        </li>
#        <li class="menu-item">
#         <a href="/commercial-office-space-for-rent-in-kenya-1.html">
#          Rent commercial property in Kenya
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="col-lg-3 col-md-3 col-sm-6">
#       <span class="seo-link-header">
#        Search
#       </span>
#       <ul>
#        <li class="menu-item">
#         <a href="/property-for-sale-in-kenya-1.html">
#          For sale
#         </a>
#        </li>
#        <li class="menu-item">
#         <a href="/property-for-rent-in-kenya-1.html">
#          For rent
#         </a>
#        </li>
#        <li class="menu-item">
#         <a href="/land-for-sale-in-kenya-1.html">
#          Land
#         </a>
#        </li>
#        <li class="menu-item">
#         <a href="/commercial-office-space-for-sale-in-kenya-1.html">
#          Commercial
#         </a>
#        </li>
#        <li class="menu-item">
#         <a href="/invest-real-estate-project-in-kenya.html">
#          New projects
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="col-lg-3 col-md-3 col-sm-6">
#       <span class="seo-link-header">
#        Services
#       </span>
#       <ul>
#        <li class="menu-item">
#         <a href="/advice">
#          Property Advice
#         </a>
#        </li>
#        <li class="menu-item">
#         <a href="/blog/category/brk-news.html">
#          Property News
#         </a>
#        </li>
#        <li class="menu-item">
#         <a href="/agents">
#          Estate Agents
#         </a>
#        </li>
#        <li class="menu-item">
#         <a href="/blog">
#          Blog
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <!-- Static SEO content -->
#     <!-- Dynamic SEO content -->
#     <div class="row">
#      <div class="col-lg-3 col-md-3 col-sm-6">
#       <span class="seo-link-header">
#        Popular buy Searches
#       </span>
#       <ul>
#        <li class="menu-item">
#         <a href="/apartments-for-sale-in-Eldoret-434.html">
#          Buy Flats / Apartments in Eldoret
#         </a>
#        </li>
#        <li class="menu-item">
#         <a href="/houses-for-sale-in-Eldoret-434.html">
#          Buy House / Villa in Eldoret
#         </a>
#        </li>
#        <li class="menu-item">
#         <a href="/townhouses-for-sale-in-Eldoret-434.html">
#          Buy Townhouse(Gated comm) in Eldoret
#         </a>
#        </li>
#        <li class="menu-item">
#         <a href="/dsq-bed-sitter-for-sale-in-Eldoret-434.html">
#          Buy Bedsitter / Room in Eldoret
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <!-- Dynamic SEO content -->
#    </div>
#   </div>
#   <!-- end footer container -->
#  </footer>
#  <div class="bottomBar">
#   <div class="container">
#    <p>
#     Copyright © Buy Rent Kenya Ltd 2014 - 2016. All Rights Reserved
#    </p>
#    <ul class="socialIcons">
#     <li>
#      <a href="https://www.facebook.com/buyrentkenya" target="_blank">
#       <img alt="" src="/88cb00e7070fce84c4e6298258d61bde/assets/images/icon-fb.png"/>
#      </a>
#     </li>
#     <li>
#      <a href="https://twitter.com/buyrentkenya" target="_blank">
#       <img alt="" src="/88cb00e7070fce84c4e6298258d61bde/assets/images/icon-twitter.png"/>
#      </a>
#     </li>
#     <li>
#      <a href="https://plus.google.com/+BuyrentkenyaNairobi" target="_blank">
#       <img alt="" src="/88cb00e7070fce84c4e6298258d61bde/assets/images/icon-google.png"/>
#      </a>
#     </li>
#     <li>
#      <a href="https://www.youtube.com/user/Buyrentkenya" target="_blank">
#       <img alt="" src="/88cb00e7070fce84c4e6298258d61bde/assets/images/icon-youtube.png"/>
#      </a>
#     </li>
#    </ul>
#   </div>
#  </div>
# </div>
# <script src="/88cb00e7070fce84c4e6298258d61bde/assets/js/libs/global.js">
# </script>
# <script src="/88cb00e7070fce84c4e6298258d61bde/assets/js/result.post.min.js">
# </script>
# <script src="/88cb00e7070fce84c4e6298258d61bde/assets/js/slider.min.js">
# </script>
# <script src="/88cb00e7070fce84c4e6298258d61bde/assets/js/multienquire.min.js">
# </script>
# <script>
#  AppendSeo();
# </script>
# <!-- Popup only if it has not appeared before -->
# <script>
#  // promptSubscription();
# </script>
# <script>
#  // Sticky block
#         jQuery(document).ready(function($) {
#             if (!!$('.sticky-block').offset()) { // Check if sticky block element exists,
#                 var stickyIndex = $('.sticky-block').index();
#                 var stickyWidth = $(".sidebar").innerWidth();
#                 $('.sidebar .block').slice(stickyIndex).wrapAll(' <div class="sticky-wrap"></div>'); // Add a wrap for sticky block and blocks below it.
#                 $('.sidebar .sticky-wrap').css({ 'width': stickyWidth}); // To avoid width of sticky wrap expand when position fixed is applied when scrolling.
#                 var sidebarHeight = $(".sidebar").height();
#                 var contentHeight = $(".content").height();
#                 if(contentHeight > sidebarHeight){
#                     sidebarHeight = contentHeight;
#                     $(".sidebar").height(sidebarHeight);
#                 }
#                 var sidebarTop = $('.sidebar').offset().top;
#                 var stickyTop = $('.sticky-block').offset().top;
#                 var stickyHeight = $('.sidebar .sticky-wrap').height();
#                 var maxScroll = sidebarTop + (sidebarHeight - stickyHeight); // Max point where the scrolling should end. Sticky should should not scroll over footer content.
#                 $(window).scroll(function(){ // Scroll event.
#                     var windowTop = $(window).scrollTop(); // Current scroll top position of window.
#
#                     if (stickyTop < windowTop && maxScroll > windowTop){ // When scrolling fix the block.
#                         $('.sidebar').css('position','static');
#                         $('.sticky-wrap').css({ 'position': 'fixed', 'top': '0px', 'z-index': 900 });
#                     }
#                     else if (maxScroll < windowTop){ // When scroll reaches end of sidebar stop scrolling.
#                         $('.sidebar').css('position','relative');
#                         $('.sticky-wrap').css({ 'position': 'absolute', 'top': 'auto', 'bottom': 0 });
#                     }
#                     else { // When sidebar top reached change everything back to normal.
#                         $('.sidebar').css('position','static');
#                         $('.sticky-wrap').css({ 'position': 'static', 'top': '150px', 'bottom': 0 });
#                     }
#                 });
#             }
#         });
# </script>
# <!-- Scripts -->
# <script>
#  var popup_open = 0;
#         var popup_delay = 10000;
#         var dpIsMobile = false;
#         var url_prefix = "http://www.buyrentkenya.com/";
#         var min_price_title = "No Min Price";
#         var max_price_title = "No Max Price";
#         var min_bed_title = "No Min bed";
#         var max_bed_title = "No Max bed";
#         var country = "TP";
#         var international = 0;
#         var lang = "en";
#         var locations = "Location";
#         var location_project = "Location or Project Name";
#         var location_agent = "Location or Agent Name";
#         var del = "Remove";
#         var select_enquire_max = "5 properties selected, please make enquiry now";
#         var adroll_segments = "fe4dca78";
#         var app_environment = "production";
#         var trovit_conversion = "";
# </script>
# <script type="text/javascript">
#  $(document).ready(function(){
#             $('#accordion-js').find('h4').click(function(){
#                 $(this).next().slideToggle();
#             }).next().hide();
#         });
# </script>
# <!-- Google Maps -->
# <script async="" defer="" src="https://maps.googleapis.com/maps/api/js?v=3&amp;key=">
# </script>
