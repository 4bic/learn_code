# %%
import requests
from bs4 import BeautifulSoup

r = requests.get("https://house.jumia.co.ke/for-sale/q:nakuru")
c = r.content
soup = BeautifulSoup(c, "html.parser")
# check source code of loaded page
#print(soup.prettify())

# extract division
all = soup.find_all("div",{"class":"listing-info"})

# %%
# check  price elements
price = all[0].find("span",{"class":"listing-price"}).text.replace(",", "")
price
# Out:
# 'KSh 4950000'

# %% [markdown]
# ## extract elements into dict and store in a list

# %%
# collect price, detail and size
data = []
for item in all:
#   create empty dictionary
    d={}
#   property name 
    d["name"] = item.find("a",{"class":"main-link"}).text.replace("\n                        ","")  
#   property address
    d["address"] = item.find("p",{"class":"listing-address icon-location"}).text
#  property value
    d["value"] = item.find("span",{"class":"listing-price"}).text.replace(",","")
#   property size / bedroom capacity
    try:
         d["description"] = item.find("span",{"class":"listing-attributes-value"}).text.replace("\n","")
    except:
        d["description"] = None
        
    data.append(d)

# %% [markdown]
# ## extracted data

# %%
data
# Out:
# [{'address': ' Lanet, Nakuru, Rift Valley',
#   'description': '3 Bedrooms',
#   'name': 'URITHI HOUSING IMPERIAL HOMES PIPELINE NAKURU                    ',
#   'value': 'KSh 4950000'},
#  {'address': 'Nakuru Nairobi Highway, Nakuru, Nakuru, Rift Valley',
#   'description': '8092 Land Size (m²)',
#   'name': 'Vacant Land For Sale In Nakuru East                    ',
#   'value': 'KSh 110000000'},
#  {'address': 'Nakuru Ndege Area, Nakuru, Nakuru, Rift Valley',
#   'description': '526 Land Size (m²)',
#   'name': 'Vacant Land For Sale In Nakuru East                    ',
#   'value': 'KSh 650000'},
#  {'address': 'Nakuru Kiamunyi, Nakuru, Nakuru, Rift Valley',
#   'description': '3 Bedrooms',
#   'name': '3 Bedroom House For Sale In Nakuru East                    ',
#   'value': 'KSh 12500000'},
#  {'address': 'Nakuru-kisumu Rd, Nakuru, Nakuru, Rift Valley',
#   'description': '1376 Land Size (m²)',
#   'name': 'Vacant Land For Sale In Nakuru East                    ',
#   'value': 'KSh 28500000'},
#  {'address': 'Nakuru Maili Saba, Nakuru, Nakuru, Rift Valley',
#   'description': '4046 Land Size (m²)',
#   'name': 'Vacant Land For Sale In Nakuru East                    ',
#   'value': 'KSh 3700000'},
#  {'address': 'Nakuru Maili 7, Nakuru, Nakuru, Rift Valley',
#   'description': '8092 Land Size (m²)',
#   'name': 'Vacant Land For Sale In Nakuru East                    ',
#   'value': 'KSh 6100000'},
#  {'address': 'nakuru highway, Nakuru, Nakuru, Rift Valley',
#   'description': '25 Rooms (total)',
#   'name': 'NAKURU BUILDING FOR SALE                    ',
#   'value': 'KSh 135000000'},
#  {'address': 'Nakuru, Nakuru, Nakuru, Rift Valley',
#   'description': '40 Rooms (total)',
#   'name': 'Modern Guest House in Nakuru Town                    ',
#   'value': 'KSh 120000000'},
#  {'address': 'Nakuru, Nakuru, Nakuru, Rift Valley',
#   'description': 'NO154LA24FLBINTRESKE-NEW Object ID',
#   'name': '2 Acre  of Land at Pipeline Estate, Approx 200 Meters off Nakuru                    ',
#   'value': 'KSh 50000000'},
#  {'address': 'Club Road, Nakuru, Nakuru, Rift Valley',
#   'description': '1 Rooms (total)',
#   'name': '1095 Sq.ft Office Suite for sale in Nakuru Town                    ',
#   'value': 'KSh 9307500'},
#  {'address': 'Club Road, Nakuru, Nakuru, Rift Valley',
#   'description': '1 Rooms (total)',
#   'name': '853 sq.ft Office Suite  for sale in  Nakuru town                    ',
#   'value': 'KSh 7250500'},
#  {'address': 'Club Road, Nakuru, Nakuru, Rift Valley',
#   'description': '1 Rooms (total)',
#   'name': '1,040 Sq.ft Office Suite for sale in Nakuru Town                    ',
#   'value': 'KSh 8840000'},
#  {'address': 'Club Road, Nakuru, Nakuru, Rift Valley',
#   'description': '1 Rooms (total)',
#   'name': '1,633 sq.ft Office Suite for sale in Nakuru Town                    ',
#   'value': 'KSh 13880500'},
#  {'address': 'Club Road, Nakuru, Nakuru, Rift Valley',
#   'description': '1 Rooms (total)',
#   'name': '1,779 sq.ft Office Suite for sale in Nakuru Town                    ',
#   'value': 'KSh 15121500'},
#  {'address': 'KITI, Nakuru, Nakuru, Rift Valley',
#   'description': '3 Bedrooms',
#   'name': 'Milimani Mountain View Apartments - Nakuru                    ',
#   'value': 'KSh 8000000'},
#  {'address': 'Bavuni Rd, Nakuru, Nakuru, Rift Valley',
#   'description': '4046 Land Size (m²)',
#   'name': 'Vacant Land For Sale In Nakuru East                    ',
#   'value': 'KSh 2300000'},
#  {'address': 'C83, Nakuru, Nakuru, Rift Valley',
#   'description': '526 Land Size (m²)',
#   'name': 'Vacant Land For Sale In Nakuru East                    ',
#   'value': 'KSh 2500000'},
#  {'address': 'Off Dondori Road, Nakuru, Nakuru, Rift Valley',
#   'description': '5 Bedrooms',
#   'name': '5 Bedroom House For Sale In Nakuru East                    ',
#   'value': 'KSh 6900000'},
#  {'address': 'Mburu Gichua Rd, Nakuru, Nakuru, Rift Valley',
#   'description': '1012 Land Size (m²)',
#   'name': 'Vacant Land For Sale In Nakuru East                    ',
#   'value': 'KSh 45000000'},
#  {'address': 'Olive Inn, Kabarak Road, Nakuru, Nakuru, Rift Valley',
#   'description': '3 Bedrooms',
#   'name': '3 Bed Room Montey Apartments In Nakuru                    ',
#   'value': 'KSh 5750000'},
#  {'address': 'Unnamed Road, Nakuru, Nakuru, Rift Valley',
#   'description': '2023000 Land Size (m²)',
#   'name': 'Vacant Land For Sale In Nakuru East                    ',
#   'value': 'KSh 400000000'},
#  {'address': 'Old Nairobi Rd, Nakuru, Nakuru, Rift Valley',
#   'description': '8092 Land Size (m²)',
#   'name': 'Vacant Land For Sale In Nakuru East                    ',
#   'value': 'KSh 90000000'},
#  {'address': 'Nakuru, Nakuru, Rift Valley',
#   'description': '465 Land Size (m²)',
#   'name': 'Prime Plots of Land  in Nakuru                    ',
#   'value': 'KSh 350000'},
#  {'address': 'Club Road, Nakuru, Rift Valley',
#   'description': '1 Rooms (total)',
#   'name': '1104 sq.ft Office Suite  for sale in Nakuru town.                    ',
#   'value': 'KSh 9384000'},
#  {'address': 'Riruta, Naivasha, Rift Valley',
#   'description': '3 Rooms (total)',
#   'name': 'LAND FOR SALE IN THE FLYOVER AREA ALONG NAIROBI-NAKURU HIGHWAY                    ',
#   'value': 'KSh 4500000'},
#  {'address': 'Nakuru- Nairobi highway, Riruta, Mbaruk, Rift Valley',
#   'description': '8094 Land Size (m²)',
#   'name': '2 Acres for sale  Along Nakuru - Nairobi Highway                    ',
#   'value': 'KSh 25000000'},
#  {'address': 'Riruta, Nakuru, Rift Valley',
#   'description': '5 Rooms (total)',
#   'name': 'HILLTOP HOLIDAY HOMES NAKURU                    ',
#   'value': 'KSh 3500000'},
#  {'address': 'Riruta, Nakuru, Rift Valley',
#   'description': '2 Rooms (total)',
#   'name': 'COTTAGES IN NAKURU                    ',
#   'value': 'KSh 3500000'},
#  {'address': ' Lanet, Nakuru, Rift Valley',
#   'description': '3 Bedrooms',
#   'name': '3 BEDROOM HOUSE IN LANET NAKURU                    ',
#   'value': 'KSh 5500000'}]

# %% [markdown]
# ## store in a data frame

# %%
import pandas as pd

df = pd.DataFrame(data)

df
# Out:
#                                               address  \
# 0                          Lanet, Nakuru, Rift Valley
# 1   Nakuru Nairobi Highway, Nakuru, Nakuru, Rift V...
# 2      Nakuru Ndege Area, Nakuru, Nakuru, Rift Valley
# 3        Nakuru Kiamunyi, Nakuru, Nakuru, Rift Valley
# 4       Nakuru-kisumu Rd, Nakuru, Nakuru, Rift Valley
# 5      Nakuru Maili Saba, Nakuru, Nakuru, Rift Valley
# 6         Nakuru Maili 7, Nakuru, Nakuru, Rift Valley
# 7         nakuru highway, Nakuru, Nakuru, Rift Valley
# 8                 Nakuru, Nakuru, Nakuru, Rift Valley
# 9                 Nakuru, Nakuru, Nakuru, Rift Valley
# 10             Club Road, Nakuru, Nakuru, Rift Valley
# 11             Club Road, Nakuru, Nakuru, Rift Valley
# 12             Club Road, Nakuru, Nakuru, Rift Valley
# 13             Club Road, Nakuru, Nakuru, Rift Valley
# 14             Club Road, Nakuru, Nakuru, Rift Valley
# 15                  KITI, Nakuru, Nakuru, Rift Valley
# 16             Bavuni Rd, Nakuru, Nakuru, Rift Valley
# 17                   C83, Nakuru, Nakuru, Rift Valley
# 18      Off Dondori Road, Nakuru, Nakuru, Rift Valley
# 19       Mburu Gichua Rd, Nakuru, Nakuru, Rift Valley
# 20  Olive Inn, Kabarak Road, Nakuru, Nakuru, Rift ...
# 21          Unnamed Road, Nakuru, Nakuru, Rift Valley
# 22        Old Nairobi Rd, Nakuru, Nakuru, Rift Valley
# 23                        Nakuru, Nakuru, Rift Valley
# 24                     Club Road, Nakuru, Rift Valley
# 25                      Riruta, Naivasha, Rift Valley
# 26  Nakuru- Nairobi highway, Riruta, Mbaruk, Rift ...
# 27                        Riruta, Nakuru, Rift Valley
# 28                        Riruta, Nakuru, Rift Valley
# 29                         Lanet, Nakuru, Rift Valley
#
#                            description  \
# 0                           3 Bedrooms
# 1                  8092 Land Size (m²)
# 2                   526 Land Size (m²)
# 3                           3 Bedrooms
# 4                  1376 Land Size (m²)
# 5                  4046 Land Size (m²)
# 6                  8092 Land Size (m²)
# 7                     25 Rooms (total)
# 8                     40 Rooms (total)
# 9   NO154LA24FLBINTRESKE-NEW Object ID
# 10                     1 Rooms (total)
# 11                     1 Rooms (total)
# 12                     1 Rooms (total)
# 13                     1 Rooms (total)
# 14                     1 Rooms (total)
# 15                          3 Bedrooms
# 16                 4046 Land Size (m²)
# 17                  526 Land Size (m²)
# 18                          5 Bedrooms
# 19                 1012 Land Size (m²)
# 20                          3 Bedrooms
# 21              2023000 Land Size (m²)
# 22                 8092 Land Size (m²)
# 23                  465 Land Size (m²)
# 24                     1 Rooms (total)
# 25                     3 Rooms (total)
# 26                 8094 Land Size (m²)
# 27                     5 Rooms (total)
# 28                     2 Rooms (total)
# 29                          3 Bedrooms
#
#                                                  name          value
# 0   URITHI HOUSING IMPERIAL HOMES PIPELINE NAKURU ...    KSh 4950000
# 1   Vacant Land For Sale In Nakuru East           ...  KSh 110000000
# 2   Vacant Land For Sale In Nakuru East           ...     KSh 650000
# 3   3 Bedroom House For Sale In Nakuru East       ...   KSh 12500000
# 4   Vacant Land For Sale In Nakuru East           ...   KSh 28500000
# 5   Vacant Land For Sale In Nakuru East           ...    KSh 3700000
# 6   Vacant Land For Sale In Nakuru East           ...    KSh 6100000
# 7        NAKURU BUILDING FOR SALE                      KSh 135000000
# 8   Modern Guest House in Nakuru Town             ...  KSh 120000000
# 9   2 Acre  of Land at Pipeline Estate, Approx 200...   KSh 50000000
# 10  1095 Sq.ft Office Suite for sale in Nakuru Tow...    KSh 9307500
# 11  853 sq.ft Office Suite  for sale in  Nakuru to...    KSh 7250500
# 12  1,040 Sq.ft Office Suite for sale in Nakuru To...    KSh 8840000
# 13  1,633 sq.ft Office Suite for sale in Nakuru To...   KSh 13880500
# 14  1,779 sq.ft Office Suite for sale in Nakuru To...   KSh 15121500
# 15  Milimani Mountain View Apartments - Nakuru    ...    KSh 8000000
# 16  Vacant Land For Sale In Nakuru East           ...    KSh 2300000
# 17  Vacant Land For Sale In Nakuru East           ...    KSh 2500000
# 18  5 Bedroom House For Sale In Nakuru East       ...    KSh 6900000
# 19  Vacant Land For Sale In Nakuru East           ...   KSh 45000000
# 20  3 Bed Room Montey Apartments In Nakuru        ...    KSh 5750000
# 21  Vacant Land For Sale In Nakuru East           ...  KSh 400000000
# 22  Vacant Land For Sale In Nakuru East           ...   KSh 90000000
# 23  Prime Plots of Land  in Nakuru                ...     KSh 350000
# 24  1104 sq.ft Office Suite  for sale in Nakuru to...    KSh 9384000
# 25  LAND FOR SALE IN THE FLYOVER AREA ALONG NAIROB...    KSh 4500000
# 26  2 Acres for sale  Along Nakuru - Nairobi Highw...   KSh 25000000
# 27   HILLTOP HOLIDAY HOMES NAKURU                        KSh 3500000
# 28             COTTAGES IN NAKURU                        KSh 3500000
# 29  3 BEDROOM HOUSE IN LANET NAKURU               ...    KSh 5500000

# %% [markdown]
# ## save to csv

# %%
df.to_csv("property_nakuru.csv")
