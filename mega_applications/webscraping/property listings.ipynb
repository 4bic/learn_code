# %%
# %matplotlib inline
import requests
from bs4 import BeautifulSoup
import pandas as pd

r = requests.get("https://house.jumia.co.ke/for-sale/")
c = r.content
soup = BeautifulSoup(c, "html.parser")
# check source code of loaded page
#print(soup.prettify())

# extract division
all = soup.find_all("div",{"class":"listing-info"})

# %%
# check  price elements
price = all[0].find("span",{"class":"listing-price"}).text.replace(",", "")
price
# Out:
# 'KSh 27500000'

# %% [markdown]
# ## extract elements into dict and store in a list

# %%
def extract_listing_detail():
#   crawl though available pages then
    # collect price, detail and size
    data = []
    for item in all:
    #   create empty dictionary
        d={}
    #   property name 
        d["name"] = (item.find("a",{"class":"main-link"}).text).strip() 
    #   property address
        d["address"] = item.find("p",{"class":"listing-address icon-location"}).text
    #  property value
        d["value"] = item.find("span",{"class":"listing-price"}).text.replace(",","")
    #   property size / bedroom capacity
        try:
             d["description"] = item.find("span",{"class":"listing-attributes-value"}).text.replace("\n","")
        except:
            d["description"] = None
    #   collect data in a list
        data.append(d)
    #   store data in a dataframe
        df = pd.DataFrame(data)
    #   save to csv
        df.to_csv("jumia_property.csv")
        
extract_listing_detail()

# %% [markdown]
# ## extracted data

# %% [markdown]
# ## store in a data frame

# %%
# df = pd.DataFrame(data)

# df

# %% [markdown]
# ## save to csv

# %%
df.to_csv("jumia_property.csv")

# %% [markdown]
# ## crawl web pages

# %%
def crawl_pages():
    base_url = "https://house.jumia.co.ke/for-sale/?page="
    for page in range(1,11,1):
        prop_page = base_url+str(page)+str("&size=30")
        r = requests.get(prop_page)
        c = r.content
        soup = BeautifulSoup(c, "html.parser")
        all = soup.find_all("div",{"class":"listing-info"})
#         call extract function 
crawl_pages()

# %% [markdown]
# # clean function crawler

# %%
# %matplotlib inline
import requests
from bs4 import BeautifulSoup
import pandas as pd

r = requests.get("https://house.jumia.co.ke/for-sale/")
c = r.content
soup = BeautifulSoup(c, "html.parser")
all = soup.find_all("div",{"class":"listing-info"})
# sample extract price
price = all[0].find("span",{"class":"listing-price"}).text.replace(",", "")

page_no = soup.find_all("li",{"class":"Pagination-item"})

page_no
# Out:
# <li class="Pagination-item Pagination-item--arrow">
# <a class="Pagination-item-link" href="/for-sale/?page=2&amp;size=30"> <span class="Pagination-item-icon icon-chevron-right"></span></a>
# </li>

# %%
base_url = "https://house.jumia.co.ke/for-sale/?page="
data = []
#   crawl though available pages to extract page no. links
for page in range(1,51,1): #used 51 since its the last page
    prop_page = base_url+str(page)+str("&size=30")
    r = requests.get(prop_page)
    c = r.content
    soup = BeautifulSoup(c, "html.parser")
    all = soup.find_all("div",{"class":"listing-info"})
# collect price, detail and size from each page
    for item in all:
        d={}
        d["name"] = (item.find("a",{"class":"main-link"}).text).strip() 
        d["address"] = item.find("p",{"class":"listing-address icon-location"}).text
        d["value"] = item.find("span",{"class":"listing-price"}).text.replace(",","")
        try:
             d["description"] = item.find("span",{"class":"listing-attributes-value"}).text.replace("\n","")
        except:
            d["description"] = None
        data.append(d)
        df = pd.DataFrame(data)
        df.to_csv("jumia_property.csv")

# %%
df
# Out:
#                                                 address  \
# 0     General Mathenge Drive, Westlands, Nairobi, Na...
# 1              Kitengela, Kajiado, Kajiado, Rift Valley
# 2                Thika, Riruta, Thika Township, Central
# 3         Mombasa Road., Mombasa Road, Nairobi, Nairobi
# 4                       Gachie, Gachie, Kiambu, Central
# 5     Church Road, Westlands, Westlands, Nairobi, Na...
# 6                     Juja South, Juja, Kiambu, Central
# 7                    South C, South C, Nairobi, Nairobi
# 8     Thika-Garissa highway, Thika Road, Nairobi, Na...
# 9                Thindigua, Thindigua, Nairobi, Nairobi
# 10                         Ruaka, Ruaka, Ruaka, Central
# 11             Upper Hill, Upper Hill, Nairobi, Nairobi
# 12           Kiambu road, Kiambu Road, Nairobi, Nairobi
# 13    Argwings Khodek Road, Hurlingham, Nairobi, Nai...
# 14              Riara Close, Kilimani, Nairobi, Nairobi
# 15    -1.249558, 36.721208, Lower Kabete, Lower Kabe...
# 16                            Mwea, Mwea, Mwea, Eastern
# 17                         Kileleshwa, Nairobi, Nairobi
# 18         Paradise Lost, Kiambu Road, Nairobi, Nairobi
# 19                             1, Riruta, , Rift Valley
# 20             Isinya Town, Riruta, Isinya, Rift Valley
# 21                 Syokimau, Syokimau, Nairobi, Nairobi
# 22              Diani creekfront, Diani, Mombasa, Coast
# 23                         Kileleshwa, Nairobi, Nairobi
# 24    Syokimau Airport Road, Syokimau, Nairobi, Nairobi
# 25                Machakos, Machakos, Machakos, Eastern
# 26                    Juja South, Juja, Kiambu, Central
# 27    Argwings Kodhek Road, Hurlingham, Nairobi, Nai...
# 28         opposite mangu high school, Nairobi, Nairobi
# 29                 Kilimani, Kilimani, Nairobi, Nairobi
# ...                                                 ...
# 1470             Riara Road, Kilimani, Nairobi, Nairobi
# 1471            Riara Road, Lavington, Nairobi, Nairobi
# 1472         Kapenguria road, Loresho, Nairobi, Nairobi
# 1473  Eastern Bypass Mihango, Utawala , Nairobi, Nai...
# 1474  MILIMANI KITENGELA, Athi River, Machakos, Eastern
# 1475                  Kuruwitu, Vipingo, Mombasa, Coast
# 1476                 KERARAPON, Karen, Nairobi, Nairobi
# 1477         Gatundu Road, Kileleshwa, Nairobi, Nairobi
# 1478                        Lavington, Nairobi, Nairobi
# 1479           peponi road, Westlands, Nairobi, Nairobi
# 1480           School lane, Brookside, Nairobi, Nairobi
# 1481    Ring Road, Kilimani, Kilimani, Nairobi, Nairobi
# 1482                     Karen, Karen, Nairobi, Nairobi
# 1483                       Ruiru, Ruiru, Ruiru, Central
# 1484                        Westlands, Nairobi, Nairobi
# 1485  Kiambu, Road Kiambu County, Riruta, Nairobi, N...
# 1486              kiambu, Kiambu Road, Nairobi, Nairobi
# 1487                         Kitisuru, Nairobi, Nairobi
# 1488          Hamisi Road, Kileleshwa, Nairobi, Nairobi
# 1489              Kilimani, Lavington, Nairobi, Nairobi
# 1490                        Westlands, Nairobi, Nairobi
# 1491      Golden Gate Estate, South B, Nairobi, Nairobi
# 1492                Ndovu road, Karen, Nairobi, Nairobi
# 1493  It's along riverside drive, Riverside, Nairobi...
# 1494                       Kileleshwa, Nairobi, Nairobi
# 1495           Riabai Road, Lavington, Nairobi, Nairobi
# 1496           school lane, Brookside, Nairobi, Nairobi
# 1497  Hatheru road off Gitanga road, Lavington, Nair...
# 1498                              Watamu, Watamu, Coast
# 1499                         Kilimani, Nairobi, Nairobi
#
#                              description  \
# 0                             3 Bedrooms
# 1                    5445 Land Size (m²)
# 2                    5000 Land Size (m²)
# 3                             4 Bedrooms
# 4                     464 Land Size (m²)
