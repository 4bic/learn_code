# %% [markdown]
# ## Network Definition and Vocabulary

# %%
import networkx as nx
# %matplotlib notebook

# %%
G = nx.Graph()
G.add_edge('A','B', weight=6)
G.add_edge('B','C', weight=13)

# %%
G.edges(data=True)
# Out:
# EdgeDataView([('A', 'B', {'weight': 6}), ('B', 'C', {'weight': 13})])

# %%
G.nodes
# Out:
# NodeView(('A', 'B', 'C'))

# %%
nx.draw_networkx(G)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Multigraphs

# %%
M=nx.MultiDiGraph()

M.add_edge('John', 'Ana', weight= 3, relation = 'siblings')
M.add_edge('Ana', 'David', weight= 4, relation = 'cousins')
M.add_edge('Ana', 'Bob', weight= 1, relation = 'friends')
M.add_edge('Ana', 'Bob', weight= 1, relation = 'neighbors')
# Out:
# 1

# %%
nx.draw_networkx(M)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from networkx.algorithms import bipartite

# %%
B = nx.Graph()

B.add_nodes_from(['A','B','C','D','E'], bipartite=0) #label one

B.add_nodes_from([1,2,3,4], bipartite=1) # second set of nodes1

#Add a list of edges 

B.add_edges_from([('A',1),('B',1),('C',1),('C',3),('D',2),('E',3),('E',4)])

# %%
X = set(['A','B','C','D','E'])

# %%
P = bipartite.projected_graph(B,X)

# %%
nx.draw_networkx(P)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
nx.draw_networkx(B)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# weighted Graphs

BG = nx.Graph()
BG.add_edges_from([('A', 'G'),('A','I'), ('B','H'), ('C', 'G'), ('C', 'I'),('D', 'H'), ('E', 'I'), ('F', 'G'), ('F', 'J')])
X1 = set(['A', 'B', 'C', 'D', 'E', 'F'])

# %%
WP = bipartite.weighted_projected_graph(BG,X)

# %%
WP['C']['A']
# Out:
# {'weight': 2}

# %%
nx.draw_networkx(BG)
# Out:
# <div id='4519e677-5623-4ef1-91cc-cfe374fd34c2'></div>

# %%
nx.draw_networkx(WP)
# Out:
# <img src="data:image/png;base64,..." width="640">
